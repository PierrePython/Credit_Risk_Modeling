])

# %%
feature_name = inputs_train.columns.values
# Stores the names of the columns of a dataframe in a variable.

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
# Creates a dataframe with a column titled 'Feature name' and row values contained in the 'feature_name' variable.
summary_table['Coefficients'] = np.transpose(reg.coef_)
# Creates a new column in the dataframe, called 'Coefficients',
# with row values the transposed coefficients from the 'LogisticRegression' object.
summary_table.index = summary_table.index + 1
# Increases the index of every row of the dataframe with 1.
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
# Assigns values of the row with index 0 of the dataframe.
summary_table = summary_table.sort_index()
# Sorts the dataframe by index.
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept      1.922374
# 1                                grade:A     -1.128252
# 2                                grade:B     -0.887760
# 3                                grade:C     -0.691840
# 4                                grade:D     -0.502270
# 5                                grade:E     -0.325286
# 6                                grade:F     -0.136716
# 7                     home_ownership:OWN     -0.091977
# 8                home_ownership:MORTGAGE     -0.107324
# 9                       addr_state:NM_VA     -0.037508
# 10                         addr_state:NY     -0.059718
# 11          addr_state:OK_TN_MO_LA_MD_NC     -0.060661
# 12                         addr_state:CA     -0.062824
# 13                addr_state:UT_KY_AZ_NJ     -0.079092
# 14             addr_state:AR_MI_PA_OH_MN     -0.136833
# 15             addr_state:RI_MA_DE_SD_IN     -0.101015
# 16                   addr_state:GA_WA_OR     -0.185487
# 17                      addr_state:WI_MT     -0.241546
# 18                         addr_state:TX     -0.224838
# 19                      addr_state:IL_CT     -0.263534
# 20          addr_state:KS_SC_CO_VT_AK_MS     -0.321805
# 21          addr_state:WV_NH_WY_DC_ME_ID     -0.523209
# 22      verification_status:Not Verified     -0.087513
# 23   verification_status:Source Verified      0.010666
# 24                   purpose:credit_card     -0.305706
# 25            purpose:debt_consolidation     -0.202305
# 26            purpose:oth__med__vacation     -0.214795
# 27   purpose:major_purch__car__home_impr     -0.267782
# 28                 initial_list_status:w     -0.053960
# 29                               term:36     -0.079338
# 30                          emp_length:1     -0.100285
# 31                        emp_length:2-4     -0.125098
# 32                        emp_length:5-6     -0.090757
# 33                        emp_length:7-9     -0.061131
# 34                         emp_length:10     -0.124642
# 35                mths_since_issue_d:<38     -1.056117
# 36              mths_since_issue_d:38-39     -0.855827
# 37              mths_since_issue_d:40-41     -0.755595
# 38              mths_since_issue_d:42-48     -0.554344
# 39              mths_since_issue_d:49-52     -0.392555
# 40              mths_since_issue_d:53-64     -0.147424
# 41              mths_since_issue_d:65-84      0.093067
# 42                       int_rate:<9.548     -0.874088
# 43                 int_rate:9.548-12.025     -0.549072
# 44                 int_rate:12.025-15.74     -0.298822
# 45                 int_rate:15.74-20.281     -0.109240
# 46   mths_since_earliest_cr_line:141-164     -0.048016
# 47   mths_since_earliest_cr_line:165-247     -0.028387
# 48   mths_since_earliest_cr_line:248-270     -0.068613
# 49   mths_since_earliest_cr_line:271-352     -0.109112
# 50      mths_since_earliest_cr_line:>352     -0.104472
# 51                         delinq_2yrs:0     -0.093762
# 52                       delinq_2yrs:1-3     -0.050955
# 53                      inq_last_6mths:0     -0.692051
# 54                    inq_last_6mths:1-2     -0.548168
# 55                    inq_last_6mths:3-6     -0.337756
# 56                          open_acc:1-3     -0.505449
# 57                         open_acc:4-12     -0.409288
# 58                        open_acc:13-17     -0.382952
# 59                        open_acc:18-22     -0.366339
# 60                        open_acc:23-25     -0.364414
# 61                        open_acc:26-30     -0.393108
# 62                         open_acc:>=31     -0.305839
# 63                           pub_rec:3-4     -0.123537
# 64                           pub_rec:>=5     -0.157049
# 65                       total_acc:28-51      0.019223
# 66                        total_acc:>=52     -0.028212
# 67                    acc_now_delinq:>=1     -0.204380
# 68               total_rev_hi_lim:5K-10K     -0.043840
# 69              total_rev_hi_lim:10K-20K     -0.013559
# 70              total_rev_hi_lim:20K-30K     -0.013540
# 71              total_rev_hi_lim:30K-40K     -0.028436
# 72              total_rev_hi_lim:40K-55K     -0.050031
# 73              total_rev_hi_lim:55K-95K     -0.076254
# 74                 total_rev_hi_lim:>95K     -0.228005
# 75                    annual_inc:20K-30K      0.068556
# 76                    annual_inc:30K-40K     -0.000214
# 77                    annual_inc:40K-50K     -0.098080
# 78                    annual_inc:50K-60K     -0.166963
# 79                    annual_inc:60K-70K     -0.242983
# 80                    annual_inc:70K-80K     -0.316804
# 81                    annual_inc:80K-90K     -0.392378
# 82                   annual_inc:90K-100K     -0.411051
# 83                  annual_inc:100K-120K     -0.488442
# 84                  annual_inc:120K-140K     -0.576660
# 85                      annual_inc:>140K     -0.503516
# 86        mths_since_last_delinq:Missing     -0.074065
# 87           mths_since_last_delinq:4-30     -0.144015
# 88          mths_since_last_delinq:31-56     -0.154559
# 89           mths_since_last_delinq:>=57     -0.106599
# 90                             dti:<=1.4     -0.207996
# 91                           dti:1.4-3.5     -0.334855
# 92                           dti:3.5-7.7     -0.364498
# 93                          dti:7.7-10.5     -0.305259
# 94                         dti:10.5-16.1     -0.229285
# 95                         dti:16.1-20.3     -0.131607
# 96                         dti:20.3-21.7     -0.120674
# 97                         dti:21.7-22.4     -0.086696
# 98                           dti:22.4-35     -0.046972
# 99        mths_since_last_record:Missing     -0.368417
# 100          mths_since_last_record:3-20     -0.458925
# 101         mths_since_last_record:21-31     -0.393282
# 102         mths_since_last_record:32-80     -0.555508
# 103         mths_since_last_record:81-86     -0.221214
# 104           mths_since_last_record:>86     -0.285468

# %% [markdown]
# ## Build a Logistic Regression Model with P-Values

# %%
# P values for sklearn logistic regression.

# Class to display p-values for logistic regression in sklearn.

import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):#,**kwargs):
        if 'max_iter' not in kwargs:
            kwargs['max_iter'] = 1000
        self.model = linear_model.LogisticRegression(*args,**kwargs)#,**args)

    def fit(self,X,y):
        self.model.fit(X,y)
        
        #### Get p-values for the fitted model ####
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X) ## Fisher Information Matrix
        Cramer_Rao = np.linalg.inv(F_ij) ## Inverse Information Matrix
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates # z-score for eaach model coefficient
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores] ### two tailed test for p-values
        
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        #self.z_scores = z_scores
        self.p_values = p_values
        #self.sigma_estimates = sigma_estimates
        #self.F_ij = F_ij

        

# 2nd solution for calculate the P-value
class LogisticRegression_with_p_values2:
    
    def __init__(self, *args, **kwargs):
        if 'max_iter' not in kwargs:
            kwargs['max_iter'] = 1000
        self.model = LogisticRegression(*args, **kwargs)

    def fit(self, X, y):
        # Ajuster le modèle
        self.model.fit(X, y.values.ravel())  # Utilisez .ravel() pour aplatir la dataframe en vecteur
        
        # Convertir les données pour statsmodels
        X_sm = sm.add_constant(X)
        model_sm = sm.Logit(y, X_sm)
        result = model_sm.fit()
        
        # Obtenir les p-values
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = result.pvalues[1:]  # Exclure l'interception

# %%
reg = LogisticRegression_with_p_values2(solver='saga')
# We create an instance of an object from the newly created 'LogisticRegression_with_p_values()' class.

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Estimates the coefficients of the object from the 'LogisticRegression' class
# with inputs (independent variables) contained in the first dataframe
# and targets (dependent variables) contained in the second dataframe.
# Out:
# Optimization terminated successfully.
#          Current function value: 0.320536
#          Iterations 7

# %%
# Same as above.
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept      1.922348
# 1                                grade:A     -1.128253
# 2                                grade:B     -0.887760
# 3                                grade:C     -0.691840
# 4                                grade:D     -0.502270
# 5                                grade:E     -0.325286
# 6                                grade:F     -0.136716
# 7                     home_ownership:OWN     -0.091976
# 8                home_ownership:MORTGAGE     -0.107324
# 9                       addr_state:NM_VA     -0.037509
# 10                         addr_state:NY     -0.059718
# 11          addr_state:OK_TN_MO_LA_MD_NC     -0.060661
# 12                         addr_state:CA     -0.062824
# 13                addr_state:UT_KY_AZ_NJ     -0.079092
# 14             addr_state:AR_MI_PA_OH_MN     -0.136833
# 15             addr_state:RI_MA_DE_SD_IN     -0.101015
# 16                   addr_state:GA_WA_OR     -0.185487
# 17                      addr_state:WI_MT     -0.241546
# 18                         addr_state:TX     -0.224838
# 19                      addr_state:IL_CT     -0.263534
# 20          addr_state:KS_SC_CO_VT_AK_MS     -0.321805
# 21          addr_state:WV_NH_WY_DC_ME_ID     -0.523208
# 22      verification_status:Not Verified     -0.087513
# 23   verification_status:Source Verified      0.010666
# 24                   purpose:credit_card     -0.305706
# 25            purpose:debt_consolidation     -0.202305
# 26            purpose:oth__med__vacation     -0.214794
# 27   purpose:major_purch__car__home_impr     -0.267782
# 28                 initial_list_status:w     -0.053960
# 29                               term:36     -0.079338
# 30                          emp_length:1     -0.100285
# 31                        emp_length:2-4     -0.125098
# 32                        emp_length:5-6     -0.090757
# 33                        emp_length:7-9     -0.061131
# 34                         emp_length:10     -0.124642
# 35                mths_since_issue_d:<38     -1.056117
# 36              mths_since_issue_d:38-39     -0.855827
# 37              mths_since_issue_d:40-41     -0.755595
# 38              mths_since_issue_d:42-48     -0.554344
# 39              mths_since_issue_d:49-52     -0.392555
# 40              mths_since_issue_d:53-64     -0.147424
# 41              mths_since_issue_d:65-84      0.093067
# 42                       int_rate:<9.548     -0.874088
# 43                 int_rate:9.548-12.025     -0.549072
# 44                 int_rate:12.025-15.74     -0.298822
# 45                 int_rate:15.74-20.281     -0.109240
# 46   mths_since_earliest_cr_line:141-164     -0.048016
# 47   mths_since_earliest_cr_line:165-247     -0.028387
# 48   mths_since_earliest_cr_line:248-270     -0.068613
# 49   mths_since_earliest_cr_line:271-352     -0.109112
# 50      mths_since_earliest_cr_line:>352     -0.104472
# 51                         delinq_2yrs:0     -0.093762
# 52                       delinq_2yrs:1-3     -0.050955
# 53                      inq_last_6mths:0     -0.692051
# 54                    inq_last_6mths:1-2     -0.548168
# 55                    inq_last_6mths:3-6     -0.337756
# 56                          open_acc:1-3     -0.505423
# 57                         open_acc:4-12     -0.409263
# 58                        open_acc:13-17     -0.382927
# 59                        open_acc:18-22     -0.366313
# 60                        open_acc:23-25     -0.364389
# 61                        open_acc:26-30     -0.393083
# 62                         open_acc:>=31     -0.305813
# 63                           pub_rec:3-4     -0.123537
# 64                           pub_rec:>=5     -0.157049
# 65                       total_acc:28-51      0.019223
# 66                        total_acc:>=52     -0.028212
# 67                    acc_now_delinq:>=1     -0.204380
# 68               total_rev_hi_lim:5K-10K     -0.043840
# 69              total_rev_hi_lim:10K-20K     -0.013559
# 70              total_rev_hi_lim:20K-30K     -0.013540
# 71              total_rev_hi_lim:30K-40K     -0.028436
# 72              total_rev_hi_lim:40K-55K     -0.050031
# 73              total_rev_hi_lim:55K-95K     -0.076254
# 74                 total_rev_hi_lim:>95K     -0.228005
# 75                    annual_inc:20K-30K      0.068556
# 76                    annual_inc:30K-40K     -0.000214
# 77                    annual_inc:40K-50K     -0.098079
# 78                    annual_inc:50K-60K     -0.166963
# 79                    annual_inc:60K-70K     -0.242983
# 80                    annual_inc:70K-80K     -0.316804
# 81                    annual_inc:80K-90K     -0.392377
# 82                   annual_inc:90K-100K     -0.411051
# 83                  annual_inc:100K-120K     -0.488442
# 84                  annual_inc:120K-140K     -0.576660
# 85                      annual_inc:>140K     -0.503516
# 86        mths_since_last_delinq:Missing     -0.074065
# 87           mths_since_last_delinq:4-30     -0.144015
# 88          mths_since_last_delinq:31-56     -0.154559
# 89           mths_since_last_delinq:>=57     -0.106599
# 90                             dti:<=1.4     -0.207996
# 91                           dti:1.4-3.5     -0.334855
# 92                           dti:3.5-7.7     -0.364497
# 93                          dti:7.7-10.5     -0.305259
# 94                         dti:10.5-16.1     -0.229285
# 95                         dti:16.1-20.3     -0.131607
# 96                         dti:20.3-21.7     -0.120674
# 97                         dti:21.7-22.4     -0.086695
# 98                           dti:22.4-35     -0.046972
# 99        mths_since_last_record:Missing     -0.368417
# 100          mths_since_last_record:3-20     -0.458925
# 101         mths_since_last_record:21-31     -0.393281
# 102         mths_since_last_record:32-80     -0.555508
# 103         mths_since_last_record:81-86     -0.221214
# 104           mths_since_last_record:>86     -0.285468

# %%
# This is a list.
p_values = reg.p_values
# We take the result of the newly added method 'p_values' and store it in a variable 'p_values'.

# %%
# Add the intercept for completeness.
p_values = np.append(np.nan, np.array(p_values))
# We add the value 'NaN' in the beginning of the variable with p-values.

# %%
summary_table['p_values'] = p_values
# In the 'summary_table' dataframe, we add a new column, called 'p_values', containing the values from the 'p_values' variable.

# %%
summary_table
# Out:
#                             Feature name  Coefficients       p_values
# 0                              Intercept      1.922348            NaN
# 1                                grade:A     -1.128253   9.588585e-36
# 2                                grade:B     -0.887760   1.963075e-48
# 3                                grade:C     -0.691840   6.568485e-35
# 4                                grade:D     -0.502270   2.993621e-21
# 5                                grade:E     -0.325286   4.996817e-12
# 6                                grade:F     -0.136716   4.189907e-03
# 7                     home_ownership:OWN     -0.091976   5.031147e-06
# 8                home_ownership:MORTGAGE     -0.107324   3.378170e-17
# 9                       addr_state:NM_VA     -0.037509   2.354035e-01
# 10                         addr_state:NY     -0.059718   1.310977e-02
# 11          addr_state:OK_TN_MO_LA_MD_NC     -0.060661   8.233561e-03
# 12                         addr_state:CA     -0.062824   2.923385e-03
# 13                addr_state:UT_KY_AZ_NJ     -0.079092   1.387717e-03
# 14             addr_state:AR_MI_PA_OH_MN     -0.136833   1.143803e-09
# 15             addr_state:RI_MA_DE_SD_IN     -0.101015   6.557813e-04
# 16                   addr_state:GA_WA_OR     -0.185487   3.269993e-12
# 17                      addr_state:WI_MT     -0.241546   3.408349e-07
# 18                         addr_state:TX     -0.224838   4.514365e-18
# 19                      addr_state:IL_CT     -0.263534   1.672282e-19
# 20          addr_state:KS_SC_CO_VT_AK_MS     -0.321805   1.478139e-25
# 21          addr_state:WV_NH_WY_DC_ME_ID     -0.523208   6.439731e-23
# 22      verification_status:Not Verified     -0.087513   2.459382e-09
# 23   verification_status:Source Verified      0.010666   4.172814e-01
# 24                   purpose:credit_card     -0.305706   5.493508e-27
# 25            purpose:debt_consolidation     -0.202305   9.656540e-15
# 26            purpose:oth__med__vacation     -0.214794   4.961702e-12
# 27   purpose:major_purch__car__home_impr     -0.267782   1.314644e-17
# 28                 initial_list_status:w     -0.053960   4.013943e-05
# 29                               term:36     -0.079338   2.465389e-08
# 30                          emp_length:1     -0.100285   1.144177e-04
# 31                        emp_length:2-4     -0.125098   4.321009e-11
# 32                        emp_length:5-6     -0.090757   2.506356e-05
# 33                        emp_length:7-9     -0.061131   3.547883e-03
# 34                         emp_length:10     -0.124642   1.643968e-11
# 35                mths_since_issue_d:<38     -1.056117  2.661818e-169
# 36              mths_since_issue_d:38-39     -0.855827  4.041496e-139
# 37              mths_since_issue_d:40-41     -0.755595  3.830830e-114
# 38              mths_since_issue_d:42-48     -0.554344   7.934395e-79
# 39              mths_since_issue_d:49-52     -0.392555   1.266394e-35
# 40              mths_since_issue_d:53-64     -0.147424   6.678232e-07
# 41              mths_since_issue_d:65-84      0.093067   1.176911e-03
# 42                       int_rate:<9.548     -0.874088   3.385025e-30
# 43                 int_rate:9.548-12.025     -0.549072   3.244245e-34
# 44                 int_rate:12.025-15.74     -0.298822   7.554328e-16
# 45                 int_rate:15.74-20.281     -0.109240   1.867613e-04
# 46   mths_since_earliest_cr_line:141-164     -0.048016   5.932078e-02
# 47   mths_since_earliest_cr_line:165-247     -0.028387   1.792945e-01
# 48   mths_since_earliest_cr_line:248-270     -0.068613   1.138052e-02
# 49   mths_since_earliest_cr_line:271-352     -0.109112   7.545932e-06
# 50      mths_since_earliest_cr_line:>352     -0.104472   1.326733e-04
# 51                         delinq_2yrs:0     -0.093762   9.539569e-02
# 52                       delinq_2yrs:1-3     -0.050955   3.354705e-01
# 53                      inq_last_6mths:0     -0.692051   8.659363e-10
# 54                    inq_last_6mths:1-2     -0.548168   9.813121e-07
# 55                    inq_last_6mths:3-6     -0.337756   2.196289e-03
# 56                          open_acc:1-3     -0.505423   1.022398e-02
# 57                         open_acc:4-12     -0.409263   1.826236e-02
# 58                        open_acc:13-17     -0.382927   2.137288e-02
# 59                        open_acc:18-22     -0.366313   2.362709e-02
# 60                        open_acc:23-25     -0.364389   2.433312e-02
# 61                        open_acc:26-30     -0.393083   2.104381e-02
# 62                         open_acc:>=31     -0.305813   3.639760e-02
# 63                           pub_rec:3-4     -0.123537   1.927038e-01
# 64                           pub_rec:>=5     -0.157049   4.007017e-01
# 65                       total_acc:28-51      0.019223   1.692061e-01
# 66                        total_acc:>=52     -0.028212   4.925865e-01
# 67                    acc_now_delinq:>=1     -0.204380   5.434718e-02
# 68               total_rev_hi_lim:5K-10K     -0.043840   8.181790e-02
# 69              total_rev_hi_lim:10K-20K     -0.013559   6.031904e-01
# 70              total_rev_hi_lim:20K-30K     -0.013540   6.403308e-01
# 71              total_rev_hi_lim:30K-40K     -0.028436   3.584896e-01
# 72              total_rev_hi_lim:40K-55K     -0.050031   1.316801e-01
# 73              total_rev_hi_lim:55K-95K     -0.076254   3.874214e-02
# 74                 total_rev_hi_lim:>95K     -0.228005   6.461957e-05
# 75                    annual_inc:20K-30K      0.068556   1.332827e-01
# 76                    annual_inc:30K-40K     -0.000214   9.149646e-01
# 77                    annual_inc:40K-50K     -0.098079   1.369588e-02
# 78                    annual_inc:50K-60K     -0.166963   4.744501e-05
# 79                    annual_inc:60K-70K     -0.242983   9.599151e-09
# 80                    annual_inc:70K-80K     -0.316804   2.920964e-13
# 81                    annual_inc:80K-90K     -0.392377   4.801062e-18
# 82                   annual_inc:90K-100K     -0.411051   1.904751e-18
# 83                  annual_inc:100K-120K     -0.488442   1.382148e-25
# 84                  annual_inc:120K-140K     -0.576660   1.218469e-27
# 85                      annual_inc:>140K     -0.503516   1.132478e-24
# 86        mths_since_last_delinq:Missing     -0.074065   2.111731e-01
# 87           mths_since_last_delinq:4-30     -0.144015   7.407368e-03
# 88          mths_since_last_delinq:31-56     -0.154559   9.284216e-03
# 89           mths_since_last_delinq:>=57     -0.106599   8.046842e-02
# 90                             dti:<=1.4     -0.207996   1.369877e-02
# 91                           dti:1.4-3.5     -0.334855   4.916890e-06
# 92                           dti:3.5-7.7     -0.364497   1.312440e-08
# 93                          dti:7.7-10.5     -0.305259   1.408405e-06
# 94                         dti:10.5-16.1     -0.229285   1.691166e-04
# 95                         dti:16.1-20.3     -0.131607   2.721858e-02
# 96                         dti:20.3-21.7     -0.120674   5.022089e-02
# 97                         dti:21.7-22.4     -0.086695   1.743497e-01
# 98                           dti:22.4-35     -0.046972   3.841719e-01
# 99        mths_since_last_record:Missing     -0.368417   8.979103e-06
# 100          mths_since_last_record:3-20     -0.458925   1.807297e-04
# 101         mths_since_last_record:21-31     -0.393281   4.625464e-04
# 102         mths_since_last_record:32-80     -0.555508   2.641992e-10
# 103         mths_since_last_record:81-86     -0.221214   2.682198e-02
# 104           mths_since_last_record:>86     -0.285468   7.549568e-04

# %%
# We are going to remove some features, the coefficients for all or almost all of the dummy variables for which,
# are not tatistically significant.

# We do that by specifying another list of dummy variables as reference categories, and a list of variables to remove.
# Then, we are going to drop the two datasets from the original list of dummy variables.

# Variables
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>86',
]]

ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>86
# 427211                           0
# 206088                           0
# 136020                           0
# 412305                           0
# 36159                            0
#
# [5 rows x 84 columns]

# %%
# Here we run a new model.
reg2 = LogisticRegression_with_p_values2()
reg2.fit(inputs_train, loan_data_targets_train)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.320606
#          Iterations 7

# %%
feature_name = inputs_train.columns.values

# %%
# Same as above.
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept      0.285875
# 1                               grade:A     -0.919195
# 2                               grade:B     -0.682024
# 3                               grade:C     -0.487724
# 4                               grade:D     -0.301685
# 5                               grade:E     -0.148087
# 6                               grade:F      0.043608
# 7                    home_ownership:OWN     -0.080723
# 8               home_ownership:MORTGAGE     -0.104898
# 9                      addr_state:NM_VA     -0.048291
# 10                        addr_state:NY     -0.068487
# 11         addr_state:OK_TN_MO_LA_MD_NC     -0.070422
# 12                        addr_state:CA     -0.076130
# 13               addr_state:UT_KY_AZ_NJ     -0.090757
# 14            addr_state:AR_MI_PA_OH_MN     -0.144463
# 15            addr_state:RI_MA_DE_SD_IN     -0.108486
# 16                  addr_state:GA_WA_OR     -0.196587
# 17                     addr_state:WI_MT     -0.238044
# 18                        addr_state:TX     -0.235403
# 19                     addr_state:IL_CT     -0.276107
# 20         addr_state:KS_SC_CO_VT_AK_MS     -0.346185
# 21         addr_state:WV_NH_WY_DC_ME_ID     -0.532143
# 22     verification_status:Not Verified     -0.085403
# 23  verification_status:Source Verified      0.009270
# 24                  purpose:credit_card     -0.278639
# 25           purpose:debt_consolidation     -0.178795
# 26           purpose:oth__med__vacation     -0.200195
# 27  purpose:major_purch__car__home_impr     -0.253347
# 28                initial_list_status:w     -0.052342
# 29                              term:36     -0.070272
# 30                         emp_length:1     -0.097493
# 31                       emp_length:2-4     -0.129849
# 32                       emp_length:5-6     -0.096627
# 33                       emp_length:7-9     -0.067485
# 34                        emp_length:10     -0.132494
# 35               mths_since_issue_d:<38     -1.138992
# 36             mths_since_issue_d:38-39     -0.912410
# 37             mths_since_issue_d:40-41     -0.823573
# 38             mths_since_issue_d:42-48     -0.625728
# 39             mths_since_issue_d:49-52     -0.472437
# 40             mths_since_issue_d:53-64     -0.225799
# 41             mths_since_issue_d:65-84      0.030679
# 42                      int_rate:<9.548     -0.947824
# 43                int_rate:9.548-12.025     -0.607130
# 44                int_rate:12.025-15.74     -0.353838
# 45                int_rate:15.74-20.281     -0.148072
# 46  mths_since_earliest_cr_line:141-164     -0.055357
# 47  mths_since_earliest_cr_line:165-247     -0.037786
# 48  mths_since_earliest_cr_line:248-270     -0.081576
# 49  mths_since_earliest_cr_line:271-352     -0.123195
# 50     mths_since_earliest_cr_line:>352     -0.122856
# 51                     inq_last_6mths:0     -0.267295
# 52                   inq_last_6mths:1-2     -0.124940
# 53                   inq_last_6mths:3-6      0.083733
# 54                   acc_now_delinq:>=1     -0.143598
# 55                   annual_inc:20K-30K      0.196162
# 56                   annual_inc:30K-40K      0.135578
# 57                   annual_inc:40K-50K      0.044705
# 58                   annual_inc:50K-60K     -0.021923
# 59                   annual_inc:60K-70K     -0.092344
# 60                   annual_inc:70K-80K     -0.167604
# 61                   annual_inc:80K-90K     -0.237180
# 62                  annual_inc:90K-100K     -0.264362
# 63                 annual_inc:100K-120K     -0.340167
# 64                 annual_inc:120K-140K     -0.403604
# 65                     annual_inc:>140K     -0.376088
# 66                            dti:<=1.4     -0.044335
# 67                          dti:1.4-3.5     -0.143463
# 68                          dti:3.5-7.7     -0.188775
# 69                         dti:7.7-10.5     -0.128609
# 70                        dti:10.5-16.1     -0.052064
# 71                        dti:16.1-20.3      0.048309
# 72                        dti:20.3-21.7      0.054907
# 73                        dti:21.7-22.4      0.097961
# 74                          dti:22.4-35      0.138627
# 75       mths_since_last_delinq:Missing     -0.054715
# 76          mths_since_last_delinq:4-30     -0.081572
# 77         mths_since_last_delinq:31-56     -0.129250
# 78          mths_since_last_delinq:>=57     -0.082053
# 79       mths_since_last_record:Missing     -0.104441
# 80          mths_since_last_record:3-20     -0.221704
# 81         mths_since_last_record:21-31     -0.155567
# 82         mths_since_last_record:32-80     -0.279192
# 83         mths_since_last_record:81-86      0.069623
# 84           mths_since_last_record:>86     -0.019178

# %%
# We add the 'p_values' here, just as we did before.
p_values = reg2.p_values
p_values = np.append(np.nan,np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Here we get the results for our final PD model.
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept      0.285875            NaN
# 1                               grade:A     -0.919195   5.228543e-36
# 2                               grade:B     -0.682024   1.444867e-48
# 3                               grade:C     -0.487724   5.078288e-35
# 4                               grade:D     -0.301685   2.345055e-21
# 5                               grade:E     -0.148087   4.065619e-12
# 6                               grade:F      0.043608   3.842305e-03
# 7                    home_ownership:OWN     -0.080723   2.957628e-06
# 8               home_ownership:MORTGAGE     -0.104898   4.055983e-17
# 9                      addr_state:NM_VA     -0.048291   2.297686e-01
# 10                        addr_state:NY     -0.068487   1.580057e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC     -0.070422   8.261890e-03
# 12                        addr_state:CA     -0.076130   2.328402e-03
# 13               addr_state:UT_KY_AZ_NJ     -0.090757   1.367798e-03
# 14            addr_state:AR_MI_PA_OH_MN     -0.144463   1.244014e-09
# 15            addr_state:RI_MA_DE_SD_IN     -0.108486   6.103984e-04
# 16                  addr_state:GA_WA_OR     -0.196587   2.309147e-12
# 17                     addr_state:WI_MT     -0.238044   3.382059e-07
# 18                        addr_state:TX     -0.235403   7.516273e-18
# 19                     addr_state:IL_CT     -0.276107   1.967860e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS     -0.346185   1.465993e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID     -0.532143   5.825112e-23
# 22     verification_status:Not Verified     -0.085403   5.521459e-09
# 23  verification_status:Source Verified      0.009270   4.033018e-01
# 24                  purpose:credit_card     -0.278639   1.675732e-26
# 25           purpose:debt_consolidation     -0.178795   2.714947e-14
# 26           purpose:oth__med__vacation     -0.200195   6.923052e-12
# 27  purpose:major_purch__car__home_impr     -0.253347   2.049396e-17
# 28                initial_list_status:w     -0.052342   3.416099e-05
# 29                              term:36     -0.070272   2.451245e-08
# 30                         emp_length:1     -0.097493   1.340395e-04
# 31                       emp_length:2-4     -0.129849   4.149322e-11
# 32                       emp_length:5-6     -0.096627   2.413170e-05
# 33                       emp_length:7-9     -0.067485   3.329767e-03
# 34                        emp_length:10     -0.132494   8.428200e-12
# 35               mths_since_issue_d:<38     -1.138992  4.771942e-179
# 36             mths_since_issue_d:38-39     -0.912410  3.275977e-148
# 37             mths_since_issue_d:40-41     -0.823573  5.639309e-122
# 38             mths_since_issue_d:42-48     -0.625728   1.945723e-85
# 39             mths_since_issue_d:49-52     -0.472437   1.242287e-38
# 40             mths_since_issue_d:53-64     -0.225799   1.238312e-07
# 41             mths_since_issue_d:65-84      0.030679   9.489601e-04
# 42                      int_rate:<9.548     -0.947824   1.060389e-30
# 43                int_rate:9.548-12.025     -0.607130   6.349835e-35
# 44                int_rate:12.025-15.74     -0.353838   2.871065e-16
# 45                int_rate:15.74-20.281     -0.148072   1.281457e-04
# 46  mths_since_earliest_cr_line:141-164     -0.055357   6.120157e-02
# 47  mths_since_earliest_cr_line:165-247     -0.037786   1.914854e-01
# 48  mths_since_earliest_cr_line:248-270     -0.081576   1.067262e-02
# 49  mths_since_earliest_cr_line:271-352     -0.123195   3.611655e-06
# 50     mths_since_earliest_cr_line:>352     -0.122856   5.335146e-05
# 51                     inq_last_6mths:0     -0.267295   5.150038e-10
# 52                   inq_last_6mths:1-2     -0.124940   7.236550e-07
# 53                   inq_last_6mths:3-6      0.083733   1.862575e-03
# 54                   acc_now_delinq:>=1     -0.143598   6.396446e-02
# 55                   annual_inc:20K-30K      0.196162   1.051865e-01
# 56                   annual_inc:30K-40K      0.135578   9.001588e-01
# 57                   annual_inc:40K-50K      0.044705   2.864444e-02
# 58                   annual_inc:50K-60K     -0.021923   1.563247e-04
# 59                   annual_inc:60K-70K     -0.092344   4.210979e-08
# 60                   annual_inc:70K-80K     -0.167604   1.375474e-12
# 61                   annual_inc:80K-90K     -0.237180   1.855527e-17
# 62                  annual_inc:90K-100K     -0.264362   5.535245e-18
# 63                 annual_inc:100K-120K     -0.340167   2.003728e-25
# 64                 annual_inc:120K-140K     -0.403604   6.624766e-28
# 65                     annual_inc:>140K     -0.376088   3.943226e-26
# 66                            dti:<=1.4     -0.044335   3.520154e-03
# 67                          dti:1.4-3.5     -0.143463   5.977388e-07
# 68                          dti:3.5-7.7     -0.188775   2.028858e-09
# 69                         dti:7.7-10.5     -0.128609   4.657782e-07
# 70                        dti:10.5-16.1     -0.052064   8.369092e-05
# 71                        dti:16.1-20.3      0.048309   2.027027e-02
# 72                        dti:20.3-21.7      0.054907   4.074991e-02
# 73                        dti:21.7-22.4      0.097961   1.531979e-01
# 74                          dti:22.4-35      0.138627   3.595815e-01
# 75       mths_since_last_delinq:Missing     -0.054715   2.824465e-02
# 76          mths_since_last_delinq:4-30     -0.081572   6.877103e-03
# 77         mths_since_last_delinq:31-56     -0.129250   4.209465e-04
# 78          mths_since_last_delinq:>=57     -0.082053   9.611698e-03
# 79       mths_since_last_record:Missing     -0.104441   3.769795e-05
# 80          mths_since_last_record:3-20     -0.221704   1.932350e-04
# 81         mths_since_last_record:21-31     -0.155567   7.901537e-04
# 82         mths_since_last_record:32-80     -0.279192   1.516691e-09
# 83         mths_since_last_record:81-86      0.069623   5.936840e-02
# 84           mths_since_last_record:>86     -0.019178   2.650404e-03

# %%
reg2

# %%
import pickle

# %%
pickle.dump(reg2, open('pd_model.sav', 'wb'))
# Here we export our model to a 'SAV' file with file name 'pd_model.sav'.

# %% [markdown]
# # PD Model Validation (Test)

# %% [markdown]
# ### Out-of-sample validation (test)

# %%
# Here, from the dataframe with inputs for testing, we keep the same variables that we used in our final PD model.
inputs_test_with_ref_cat = loan_data_inputs_test.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>86',
]]

# %%
# And here, in the list below, we keep the variable names for the reference categories,
# only for the variables we used in our final PD model.
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_test = inputs_test_with_ref_cat.drop(ref_categories, axis = 1)
inputs_test.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514        0        0        1        0        0        0
# 288564        0        0        0        0        1        0
# 213591        0        0        1        0        0        0
# 263083        0        0        1        0        0        0
# 165001        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 362514              0  ...                               1
# 288564              0  ...                               0
# 213591              0  ...                               0
# 263083              0  ...                               1
# 165001              0  ...                               0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:>86
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0
#
# [5 rows x 84 columns]

# %%
y_hat_test = reg2.model.predict(inputs_test)
# Calculates the predicted values for the dependent variable (targets)
# based on the values of the independent variables (inputs) supplied as an argument.

# %%
y_hat_test
# This is an array of predicted discrete classess (in this case, 0s and 1s).
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_hat_test_proba = reg2.model.predict_proba(inputs_test)
# Calculates the predicted probability values for the dependent variable (targets)
# based on the values of the independent variables (inputs) supplied as an argument.

# %%
y_hat_test_proba
# This is an array of arrays of predicted class probabilities for all classes.
# In this case, the first value of every sub-array is the probability for the observation to belong to the first class, i.e. 0,
# and the second value is the probability for the observation to belong to the first class, i.e. 1.
# Out:
# array([[0.92405945, 0.07594055],
#        [0.85123214, 0.14876786],
#        [0.88433585, 0.11566415],
#        ...,
#        [0.9736933 , 0.0263067 ],
#        [0.96043421, 0.03956579],
#        [0.95259674, 0.04740326]])

# %%
y_hat_test_proba[:][:,1]
# Here we take all the arrays in the array, and from each array, we take all rows, and only the element with index 1,
# that is, the second element.
# In other words, we take only the probabilities for being 1.
# Out:
# array([0.07594055, 0.14876786, 0.11566415, ..., 0.0263067 , 0.03956579,
#        0.04740326])

# %%
y_hat_test_proba = y_hat_test_proba[: ][: , 1]
# We store these probabilities in a variable.

# %%
y_hat_test_proba
# This variable contains an array of probabilities of being 1.
# Out:
# array([0.07594055, 0.14876786, 0.11566415, ..., 0.0263067 , 0.03956579,
#        0.04740326])

# %%
loan_data_targets_test_temp = loan_data_targets_test

# %%
loan_data_targets_test_temp.reset_index(drop = True, inplace = True)
# We reset the index of a dataframe.

# %%
df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp, pd.DataFrame(y_hat_test_proba)], axis = 1)
# Concatenates two dataframes.

# %%
df_actual_predicted_probs.shape
# Out:
# (93257, 2)

# %%
df_actual_predicted_probs.columns = ['loan_data_targets_test', 'y_hat_test_proba']

# %%
df_actual_predicted_probs.index = loan_data_inputs_test.index
# Makes the index of one dataframe equal to the index of another dataframe.

# %%
df_actual_predicted_probs.head()
# Out:
#         loan_data_targets_test  y_hat_test_proba
# 362514                       0          0.075941
# 288564                       0          0.148768
# 213591                       0          0.115664
# 263083                       0          0.059176
# 165001                       0          0.031447

# %% [markdown]
# ### Accuracy and Area under the Curve

# %%
tr = 0.1
# We create a new column with an indicator,
# where every observation that has predicted probability greater than the threshold has a value of 1,
# and every observation that has predicted probability lower than the threshold has a value of 0.
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted'])
# Creates a cross-table where the actual values are displayed by rows and the predicted values by columns.
# This table is known as a Confusion Matrix.
# Out:
# Predicted      0      1
# Actual
# 0          47188  35879
# 1           2812   7378

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Here we divide each value of the table by the total number of observations,
# thus getting percentages, or, rates.
# Out:
# Predicted         0         1
# Actual
# 0          0.506000  0.384733
# 1          0.030153  0.079115

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Here we calculate Accuracy of the model, which is the sum of the diagonal rates.
# Out:
# 0.5851142541578649

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Returns the Receiver Operating Characteristic (ROC) Curve from a set of actual values and their predicted probabilities.
# As a result, we get three arrays: the false positive rates, the true positive rates, and the thresholds.
# Out:
# (array([0.00000000e+00, 0.00000000e+00, 1.20384750e-05, ...,
#         9.99855538e-01, 9.99855538e-01, 1.00000000e+00]),
#  array([0.00000000e+00, 9.81354269e-05, 9.81354269e-05, ...,
#         9.99901865e-01, 1.00000000e+00, 1.00000000e+00]),
#  array([       inf, 0.51111718, 0.503247  , ..., 0.00955576, 0.00955506,
#         0.00759682]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Here we store each of the three arrays in a separate variable.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
# We plot the false positive rate along the x-axis and the true positive rate along the y-axis,
# thus plotting the ROC curve.
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
# We plot a seconary diagonal line, with dashed line style and black color.
plt.xlabel('False positive rate')
# We name the x-axis "False positive rate".
plt.ylabel('True positive rate')
# We name the x-axis "True positive rate".
plt.title('ROC curve')
# We name the graph "ROC curve".
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
AUROC = roc_auc_score(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Calculates the Area Under the Receiver Operating Characteristic Curve (AUROC)
# from a set of actual values and their predicted probabilities.
AUROC
# Out:
# 0.7016794836257425

# %% [markdown]
# ### Gini and Kolmogorov-Smirnov

# %%
df_actual_predicted_probs = df_actual_predicted_probs.sort_values('y_hat_test_proba', ascending=False)
# Sorts a dataframe by the values of a specific column.

# %%
df_actual_predicted_probs.head()
# Out:
#         loan_data_targets_test  y_hat_test_proba  y_hat_test
# 11208                        1          0.511117           1
# 118702                       0          0.503247           1
# 210472                       1          0.500960           1
# 165242                       0          0.480914           1
# 2808                         1          0.477761           1

# %%
df_actual_predicted_probs.tail()
# Out:
#         loan_data_targets_test  y_hat_test_proba  y_hat_test
# 239098                       0          0.008759           0
# 262480                       0          0.008641           0
# 239228                       0          0.008237           0
# 261086                       0          0.008122           0
# 242624                       0          0.007597           0

# %%
df_actual_predicted_probs = df_actual_predicted_probs.reset_index()
# We reset the index of a dataframe and overwrite it.

# %%
#df_actual_predicted_probs = df_actual_predicted_probs.drop('level_0', axis=1)
df_actual_predicted_probs.head()
# Out:
#     index  loan_data_targets_test  y_hat_test_proba  y_hat_test
# 0   11208                       1          0.511117           1
# 1  118702                       0          0.503247           1
# 2  210472                       1          0.500960           1
# 3  165242                       0          0.480914           1
# 4    2808                       1          0.477761           1

# %%
df_actual_predicted_probs['Cumulative N Population'] = df_actual_predicted_probs.index + 1
# We calculate the cumulative number of all observations.
# We use the new index for that. Since indexing in ython starts from 0, we add 1 to each index.
df_actual_predicted_probs['Cumulative N Bad'] = df_actual_predicted_probs['loan_data_targets_test'].cumsum()
# We calculate cumulative number of 'bad', which is the cumulative sum of the column with actual observations.
df_actual_predicted_probs['Cumulative N Good'] = df_actual_predicted_probs['Cumulative N Population'] - df_actual_predicted_probs['loan_data_targets_test'].cumsum()
# We calculate cumulative number of 'good', which is
# the difference between the cumulative number of all observations and cumulative number of 'good' for each row.

# %%
df_actual_predicted_probs.head()
# Out:
#     index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0   11208                       1          0.511117           1
# 1  118702                       0          0.503247           1
# 2  210472                       1          0.500960           1
# 3  165242                       0          0.480914           1
# 4    2808                       1          0.477761           1
#
#    Cumulative N Population  Cumulative N Bad  Cumulative N Good
# 0                        1                 1                  0
# 1                        2                 1                  1
# 2                        3                 2                  1
# 3                        4                 2                  2
# 4                        5                 3                  2

# %%
df_actual_predicted_probs['Cumulative Perc Population'] = df_actual_predicted_probs['Cumulative N Population'] / (df_actual_predicted_probs.shape[0])
# We calculate the cumulative percentage of all observations.
df_actual_predicted_probs['Cumulative Perc Bad'] = df_actual_predicted_probs['Cumulative N Bad'] / df_actual_predicted_probs['loan_data_targets_test'].sum()
# We calculate cumulative percentage of 'good'.
df_actual_predicted_probs['Cumulative Perc Good'] = df_actual_predicted_probs['Cumulative N Good'] / (df_actual_predicted_probs.shape[0] - df_actual_predicted_probs['loan_data_targets_test'].sum())
# We calculate the cumulative percentage of 'bad'.

# %%
df_actual_predicted_probs.head()
# Out:
#     index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0   11208                       1          0.511117           1
# 1  118702                       0          0.503247           1
# 2  210472                       1          0.500960           1
# 3  165242                       0          0.480914           1
# 4    2808                       1          0.477761           1
#
#    Cumulative N Population  Cumulative N Bad  Cumulative N Good  \
# 0                        1                 1                  0
# 1                        2                 1                  1
# 2                        3                 2                  1
# 3                        4                 2                  2
# 4                        5                 3                  2
#
#    Cumulative Perc Population  Cumulative Perc Bad  Cumulative Perc Good
# 0                    0.000011             0.000098              0.000000
# 1                    0.000021             0.000098              0.000012
# 2                    0.000032             0.000196              0.000012
# 3                    0.000043             0.000196              0.000024
# 4                    0.000054             0.000294              0.000024

# %%
df_actual_predicted_probs.tail()
# Out:
#         index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 93252  239098                       0          0.008759           0
# 93253  262480                       0          0.008641           0
# 93254  239228                       0          0.008237           0
# 93255  261086                       0          0.008122           0
# 93256  242624                       0          0.007597           0
#
#        Cumulative N Population  Cumulative N Bad  Cumulative N Good  \
# 93252                    93253             10190              83063
# 93253                    93254             10190              83064
# 93254                    93255             10190              83065
# 93255                    93256             10190              83066
# 93256                    93257             10190              83067
#
#        Cumulative Perc Population  Cumulative Perc Bad  Cumulative Perc Good
# 93252                    0.999957                  1.0              0.999952
# 93253                    0.999968                  1.0              0.999964
# 93254                    0.999979                  1.0              0.999976
# 93255                    0.999989                  1.0              0.999988
# 93256                    1.000000                  1.0              1.000000

# %%
# Plot Gini
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], df_actual_predicted_probs['Cumulative Perc Bad'])
# We plot the cumulative percentage of all along the x-axis and the cumulative percentage 'good' along the y-axis,
# thus plotting the Gini curve.
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], df_actual_predicted_probs['Cumulative Perc Population'], linestyle = '--', color = 'k')
# We plot a seconary diagonal line, with dashed line style and black color.
plt.xlabel('Cumulative % Population')
# We name the x-axis "Cumulative % Population".
plt.ylabel('Cumulative % Bad')
# We name the y-axis "Cumulative % Bad".
plt.title('Gini')
# We name the graph "Gini".
# Out:
# Text(0.5, 1.0, 'Gini')

# %%
Gini = AUROC * 2 - 1
# Here we calculate Gini from AUROC.
Gini
# Out:
# 0.403358967251485

# %%
# Plot KS
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], df_actual_predicted_probs['Cumulative Perc Bad'], color = 'r')
# We plot the predicted (estimated) probabilities along the x-axis and the cumulative percentage 'bad' along the y-axis,
# colored in red.
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], df_actual_predicted_probs['Cumulative Perc Good'], color = 'b')
# We plot the predicted (estimated) probabilities along the x-axis and the cumulative percentage 'good' along the y-axis,
# colored in red.
plt.xlabel('Estimated Probability for being Good')
# We name the x-axis "Estimated Probability for being Good".
plt.ylabel('Cumulative %')
# We name the y-axis "Cumulative %".
plt.title('Kolmogorov-Smirnov')
# We name the graph "Kolmogorov-Smirnov".
# Out:
# Text(0.5, 1.0, 'Kolmogorov-Smirnov')

# %%
KS = max(df_actual_predicted_probs['Cumulative Perc Bad'] - df_actual_predicted_probs['Cumulative Perc Good'])
# We calculate KS from the data. It is the maximum of the difference between the cumulative percentage of 'bad'
# and the cumulative percentage of 'good'.
KS
# Out:
# 0.2969822910252768

# %% [markdown]
# # Applying the PD Model

# %% [markdown]
# ### Calculating PD of individual accounts

# %%
pd.options.display.max_columns = None
# Sets the pandas dataframe options to display all columns/ rows.

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>86
# 362514                             0                           0
# 288564                             0                           0
# 213591                             0                           0
# 263083                             0                           0
# 165001                             0                           0

# %%
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept      0.285875            NaN
# 1                               grade:A     -0.919195   5.228543e-36
# 2                               grade:B     -0.682024   1.444867e-48
# 3                               grade:C     -0.487724   5.078288e-35
# 4                               grade:D     -0.301685   2.345055e-21
# 5                               grade:E     -0.148087   4.065619e-12
# 6                               grade:F      0.043608   3.842305e-03
# 7                    home_ownership:OWN     -0.080723   2.957628e-06
# 8               home_ownership:MORTGAGE     -0.104898   4.055983e-17
# 9                      addr_state:NM_VA     -0.048291   2.297686e-01
# 10                        addr_state:NY     -0.068487   1.580057e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC     -0.070422   8.261890e-03
# 12                        addr_state:CA     -0.076130   2.328402e-03
# 13               addr_state:UT_KY_AZ_NJ     -0.090757   1.367798e-03
# 14            addr_state:AR_MI_PA_OH_MN     -0.144463   1.244014e-09
# 15            addr_state:RI_MA_DE_SD_IN     -0.108486   6.103984e-04
# 16                  addr_state:GA_WA_OR     -0.196587   2.309147e-12
# 17                     addr_state:WI_MT     -0.238044   3.382059e-07
# 18                        addr_state:TX     -0.235403   7.516273e-18
# 19                     addr_state:IL_CT     -0.276107   1.967860e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS     -0.346185   1.465993e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID     -0.532143   5.825112e-23
# 22     verification_status:Not Verified     -0.085403   5.521459e-09
# 23  verification_status:Source Verified      0.009270   4.033018e-01
# 24                  purpose:credit_card     -0.278639   1.675732e-26
# 25           purpose:debt_consolidation     -0.178795   2.714947e-14
# 26           purpose:oth__med__vacation     -0.200195   6.923052e-12
# 27  purpose:major_purch__car__home_impr     -0.253347   2.049396e-17
# 28                initial_list_status:w     -0.052342   3.416099e-05
# 29                              term:36     -0.070272   2.451245e-08
# 30                         emp_length:1     -0.097493   1.340395e-04
# 31                       emp_length:2-4     -0.129849   4.149322e-11
# 32                       emp_length:5-6     -0.096627   2.413170e-05
# 33                       emp_length:7-9     -0.067485   3.329767e-03
# 34                        emp_length:10     -0.132494   8.428200e-12
# 35               mths_since_issue_d:<38     -1.138992  4.771942e-179
# 36             mths_since_issue_d:38-39     -0.912410  3.275977e-148
# 37             mths_since_issue_d:40-41     -0.823573  5.639309e-122
# 38             mths_since_issue_d:42-48     -0.625728   1.945723e-85
# 39             mths_since_issue_d:49-52     -0.472437   1.242287e-38
# 40             mths_since_issue_d:53-64     -0.225799   1.238312e-07
# 41             mths_since_issue_d:65-84      0.030679   9.489601e-04
# 42                      int_rate:<9.548     -0.947824   1.060389e-30
# 43                int_rate:9.548-12.025     -0.607130   6.349835e-35
# 44                int_rate:12.025-15.74     -0.353838   2.871065e-16
# 45                int_rate:15.74-20.281     -0.148072   1.281457e-04
# 46  mths_since_earliest_cr_line:141-164     -0.055357   6.120157e-02
# 47  mths_since_earliest_cr_line:165-247     -0.037786   1.914854e-01
# 48  mths_since_earliest_cr_line:248-270     -0.081576   1.067262e-02
# 49  mths_since_earliest_cr_line:271-352     -0.123195   3.611655e-06
# 50     mths_since_earliest_cr_line:>352     -0.122856   5.335146e-05
# 51                     inq_last_6mths:0     -0.267295   5.150038e-10
# 52                   inq_last_6mths:1-2     -0.124940   7.236550e-07
# 53                   inq_last_6mths:3-6      0.083733   1.862575e-03
# 54                   acc_now_delinq:>=1     -0.143598   6.396446e-02
# 55                   annual_inc:20K-30K      0.196162   1.051865e-01
# 56                   annual_inc:30K-40K      0.135578   9.001588e-01
# 57                   annual_inc:40K-50K      0.044705   2.864444e-02
# 58                   annual_inc:50K-60K     -0.021923   1.563247e-04
# 59                   annual_inc:60K-70K     -0.092344   4.210979e-08
# 60                   annual_inc:70K-80K     -0.167604   1.375474e-12
# 61                   annual_inc:80K-90K     -0.237180   1.855527e-17
# 62                  annual_inc:90K-100K     -0.264362   5.535245e-18
# 63                 annual_inc:100K-120K     -0.340167   2.003728e-25
# 64                 annual_inc:120K-140K     -0.403604   6.624766e-28
# 65                     annual_inc:>140K     -0.376088   3.943226e-26
# 66                            dti:<=1.4     -0.044335   3.520154e-03
# 67                          dti:1.4-3.5     -0.143463   5.977388e-07
# 68                          dti:3.5-7.7     -0.188775   2.028858e-09
# 69                         dti:7.7-10.5     -0.128609   4.657782e-07
# 70                        dti:10.5-16.1     -0.052064   8.369092e-05
# 71                        dti:16.1-20.3      0.048309   2.027027e-02
# 72                        dti:20.3-21.7      0.054907   4.074991e-02
# 73                        dti:21.7-22.4      0.097961   1.531979e-01
# 74                          dti:22.4-35      0.138627   3.595815e-01
# 75       mths_since_last_delinq:Missing     -0.054715   2.824465e-02
# 76          mths_since_last_delinq:4-30     -0.081572   6.877103e-03
# 77         mths_since_last_delinq:31-56     -0.129250   4.209465e-04
# 78          mths_since_last_delinq:>=57     -0.082053   9.611698e-03
# 79       mths_since_last_record:Missing     -0.104441   3.769795e-05
# 80          mths_since_last_record:3-20     -0.221704   1.932350e-04
# 81         mths_since_last_record:21-31     -0.155567   7.901537e-04
# 82         mths_since_last_record:32-80     -0.279192   1.516691e-09
# 83         mths_since_last_record:81-86      0.069623   5.936840e-02
# 84           mths_since_last_record:>86     -0.019178   2.650404e-03

# %%
y_hat_test_proba
# Out:
# array([0.07594055, 0.14876786, 0.11566415, ..., 0.0263067 , 0.03956579,
#        0.04740326])

# %% [markdown]
# ### Creating a Scorecard

# %%
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept      0.285875            NaN
# 1                               grade:A     -0.919195   5.228543e-36
# 2                               grade:B     -0.682024   1.444867e-48
# 3                               grade:C     -0.487724   5.078288e-35
# 4                               grade:D     -0.301685   2.345055e-21
# 5                               grade:E     -0.148087   4.065619e-12
# 6                               grade:F      0.043608   3.842305e-03
# 7                    home_ownership:OWN     -0.080723   2.957628e-06
# 8               home_ownership:MORTGAGE     -0.104898   4.055983e-17
# 9                      addr_state:NM_VA     -0.048291   2.297686e-01
# 10                        addr_state:NY     -0.068487   1.580057e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC     -0.070422   8.261890e-03
# 12                        addr_state:CA     -0.076130   2.328402e-03
# 13               addr_state:UT_KY_AZ_NJ     -0.090757   1.367798e-03
# 14            addr_state:AR_MI_PA_OH_MN     -0.144463   1.244014e-09
# 15            addr_state:RI_MA_DE_SD_IN     -0.108486   6.103984e-04
# 16                  addr_state:GA_WA_OR     -0.196587   2.309147e-12
# 17                     addr_state:WI_MT     -0.238044   3.382059e-07
# 18                        addr_state:TX     -0.235403   7.516273e-18
# 19                     addr_state:IL_CT     -0.276107   1.967860e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS     -0.346185   1.465993e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID     -0.532143   5.825112e-23
# 22     verification_status:Not Verified     -0.085403   5.521459e-09
# 23  verification_status:Source Verified      0.009270   4.033018e-01
# 24                  purpose:credit_card     -0.278639   1.675732e-26
# 25           purpose:debt_consolidation     -0.178795   2.714947e-14
# 26           purpose:oth__med__vacation     -0.200195   6.923052e-12
# 27  purpose:major_purch__car__home_impr     -0.253347   2.049396e-17
# 28                initial_list_status:w     -0.052342   3.416099e-05
# 29                              term:36     -0.070272   2.451245e-08
# 30                         emp_length:1     -0.097493   1.340395e-04
# 31                       emp_length:2-4     -0.129849   4.149322e-11
# 32                       emp_length:5-6     -0.096627   2.413170e-05
# 33                       emp_length:7-9     -0.067485   3.329767e-03
# 34                        emp_length:10     -0.132494   8.428200e-12
# 35               mths_since_issue_d:<38     -1.138992  4.771942e-179
# 36             mths_since_issue_d:38-39     -0.912410  3.275977e-148
# 37             mths_since_issue_d:40-41     -0.823573  5.639309e-122
# 38             mths_since_issue_d:42-48     -0.625728   1.945723e-85
# 39             mths_since_issue_d:49-52     -0.472437   1.242287e-38
# 40             mths_since_issue_d:53-64     -0.225799   1.238312e-07
# 41             mths_since_issue_d:65-84      0.030679   9.489601e-04
# 42                      int_rate:<9.548     -0.947824   1.060389e-30
# 43                int_rate:9.548-12.025     -0.607130   6.349835e-35
# 44                int_rate:12.025-15.74     -0.353838   2.871065e-16
# 45                int_rate:15.74-20.281     -0.148072   1.281457e-04
# 46  mths_since_earliest_cr_line:141-164     -0.055357   6.120157e-02
# 47  mths_since_earliest_cr_line:165-247     -0.037786   1.914854e-01
# 48  mths_since_earliest_cr_line:248-270     -0.081576   1.067262e-02
# 49  mths_since_earliest_cr_line:271-352     -0.123195   3.611655e-06
# 50     mths_since_earliest_cr_line:>352     -0.122856   5.335146e-05
# 51                     inq_last_6mths:0     -0.267295   5.150038e-10
# 52                   inq_last_6mths:1-2     -0.124940   7.236550e-07
# 53                   inq_last_6mths:3-6      0.083733   1.862575e-03
# 54                   acc_now_delinq:>=1     -0.143598   6.396446e-02
# 55                   annual_inc:20K-30K      0.196162   1.051865e-01
# 56                   annual_inc:30K-40K      0.135578   9.001588e-01
# 57                   annual_inc:40K-50K      0.044705   2.864444e-02
# 58                   annual_inc:50K-60K     -0.021923   1.563247e-04
# 59                   annual_inc:60K-70K     -0.092344   4.210979e-08
# 60                   annual_inc:70K-80K     -0.167604   1.375474e-12
# 61                   annual_inc:80K-90K     -0.237180   1.855527e-17
# 62                  annual_inc:90K-100K     -0.264362   5.535245e-18
# 63                 annual_inc:100K-120K     -0.340167   2.003728e-25
# 64                 annual_inc:120K-140K     -0.403604   6.624766e-28
# 65                     annual_inc:>140K     -0.376088   3.943226e-26
# 66                            dti:<=1.4     -0.044335   3.520154e-03
# 67                          dti:1.4-3.5     -0.143463   5.977388e-07
# 68                          dti:3.5-7.7     -0.188775   2.028858e-09
# 69                         dti:7.7-10.5     -0.128609   4.657782e-07
# 70                        dti:10.5-16.1     -0.052064   8.369092e-05
# 71                        dti:16.1-20.3      0.048309   2.027027e-02
# 72                        dti:20.3-21.7      0.054907   4.074991e-02
# 73                        dti:21.7-22.4      0.097961   1.531979e-01
# 74                          dti:22.4-35      0.138627   3.595815e-01
# 75       mths_since_last_delinq:Missing     -0.054715   2.824465e-02
# 76          mths_since_last_delinq:4-30     -0.081572   6.877103e-03
# 77         mths_since_last_delinq:31-56     -0.129250   4.209465e-04
# 78          mths_since_last_delinq:>=57     -0.082053   9.611698e-03
# 79       mths_since_last_record:Missing     -0.104441   3.769795e-05
# 80          mths_since_last_record:3-20     -0.221704   1.932350e-04
# 81         mths_since_last_record:21-31     -0.155567   7.901537e-04
# 82         mths_since_last_record:32-80     -0.279192   1.516691e-09
# 83         mths_since_last_record:81-86      0.069623   5.936840e-02
# 84           mths_since_last_record:>86     -0.019178   2.650404e-03

# %%
ref_categories
# Out:
# ['grade:G',
#  'home_ownership:RENT_OTHER_NONE_ANY',
#  'addr_state:ND_NE_IA_NV_FL_HI_AL',
#  'verification_status:Verified',
#  'purpose:educ__sm_b__wedd__ren_en__mov__house',
#  'initial_list_status:f',
#  'term:60',
#  'emp_length:0',
#  'mths_since_issue_d:>84',
#  'int_rate:>20.281',
#  'mths_since_earliest_cr_line:<140',
#  'inq_last_6mths:>6',
#  'acc_now_delinq:0',
#  'annual_inc:<20K',
#  'dti:>35',
#  'mths_since_last_delinq:0-3',
#  'mths_since_last_record:0-2']

# %%
df_ref_categories = pd.DataFrame(ref_categories, columns = ['Feature name'])
# We create a new dataframe with one column. Its values are the values from the 'reference_categories' list.
# We name it 'Feature name'.
df_ref_categories['Coefficients'] = 0
# We create a second column, called 'Coefficients', which contains only 0 values.
df_ref_categories['p_values'] = np.nan
# We create a third column, called 'p_values', with contains only NaN values.
df_ref_categories
# Out:
#                                     Feature name  Coefficients  p_values
# 0                                        grade:G             0       NaN
# 1             home_ownership:RENT_OTHER_NONE_ANY             0       NaN
# 2                addr_state:ND_NE_IA_NV_FL_HI_AL             0       NaN
# 3                   verification_status:Verified             0       NaN
# 4   purpose:educ__sm_b__wedd__ren_en__mov__house             0       NaN
# 5                          initial_list_status:f             0       NaN
# 6                                        term:60             0       NaN
# 7                                   emp_length:0             0       NaN
# 8                         mths_since_issue_d:>84             0       NaN
# 9                               int_rate:>20.281             0       NaN
# 10              mths_since_earliest_cr_line:<140             0       NaN
# 11                             inq_last_6mths:>6             0       NaN
# 12                              acc_now_delinq:0             0       NaN
# 13                               annual_inc:<20K             0       NaN
# 14                                       dti:>35             0       NaN
# 15                    mths_since_last_delinq:0-3             0       NaN
# 16                    mths_since_last_record:0-2             0       NaN

# %%
df_scorecard = pd.concat([summary_table, df_ref_categories])
# Concatenates two dataframes.
df_scorecard = df_scorecard.reset_index()
# We reset the index of a dataframe.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept      0.285875
# 1        1                                       grade:A     -0.919195
# 2        2                                       grade:B     -0.682024
# 3        3                                       grade:C     -0.487724
# 4        4                                       grade:D     -0.301685
# 5        5                                       grade:E     -0.148087
# 6        6                                       grade:F      0.043608
# 7        7                            home_ownership:OWN     -0.080723
# 8        8                       home_ownership:MORTGAGE     -0.104898
# 9        9                              addr_state:NM_VA     -0.048291
# 10      10                                 addr_state:NY     -0.068487
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC     -0.070422
# 12      12                                 addr_state:CA     -0.076130
# 13      13                        addr_state:UT_KY_AZ_NJ     -0.090757
# 14      14                     addr_state:AR_MI_PA_OH_MN     -0.144463
# 15      15                     addr_state:RI_MA_DE_SD_IN     -0.108486
# 16      16                           addr_state:GA_WA_OR     -0.196587
# 17      17                              addr_state:WI_MT     -0.238044
# 18      18                                 addr_state:TX     -0.235403
# 19      19                              addr_state:IL_CT     -0.276107
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS     -0.346185
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID     -0.532143
# 22      22              verification_status:Not Verified     -0.085403
# 23      23           verification_status:Source Verified      0.009270
# 24      24                           purpose:credit_card     -0.278639
# 25      25                    purpose:debt_consolidation     -0.178795
# 26      26                    purpose:oth__med__vacation     -0.200195
# 27      27           purpose:major_purch__car__home_impr     -0.253347
# 28      28                         initial_list_status:w     -0.052342
# 29      29                                       term:36     -0.070272
# 30      30                                  emp_length:1     -0.097493
# 31      31                                emp_length:2-4     -0.129849
# 32      32                                emp_length:5-6     -0.096627
# 33      33                                emp_length:7-9     -0.067485
# 34      34                                 emp_length:10     -0.132494
# 35      35                        mths_since_issue_d:<38     -1.138992
# 36      36                      mths_since_issue_d:38-39     -0.912410
# 37      37                      mths_since_issue_d:40-41     -0.823573
# 38      38                      mths_since_issue_d:42-48     -0.625728
# 39      39                      mths_since_issue_d:49-52     -0.472437
# 40      40                      mths_since_issue_d:53-64     -0.225799
# 41      41                      mths_since_issue_d:65-84      0.030679
# 42      42                               int_rate:<9.548     -0.947824
# 43      43                         int_rate:9.548-12.025     -0.607130
# 44      44                         int_rate:12.025-15.74     -0.353838
# 45      45                         int_rate:15.74-20.281     -0.148072
# 46      46           mths_since_earliest_cr_line:141-164     -0.055357
# 47      47           mths_since_earliest_cr_line:165-247     -0.037786
# 48      48           mths_since_earliest_cr_line:248-270     -0.081576
# 49      49           mths_since_earliest_cr_line:271-352     -0.123195
# 50      50              mths_since_earliest_cr_line:>352     -0.122856
# 51      51                              inq_last_6mths:0     -0.267295
# 52      52                            inq_last_6mths:1-2     -0.124940
# 53      53                            inq_last_6mths:3-6      0.083733
# 54      54                            acc_now_delinq:>=1     -0.143598
# 55      55                            annual_inc:20K-30K      0.196162
# 56      56                            annual_inc:30K-40K      0.135578
# 57      57                            annual_inc:40K-50K      0.044705
# 58      58                            annual_inc:50K-60K     -0.021923
# 59      59                            annual_inc:60K-70K     -0.092344
# 60      60                            annual_inc:70K-80K     -0.167604
# 61      61                            annual_inc:80K-90K     -0.237180
# 62      62                           annual_inc:90K-100K     -0.264362
# 63      63                          annual_inc:100K-120K     -0.340167
# 64      64                          annual_inc:120K-140K     -0.403604
# 65      65                              annual_inc:>140K     -0.376088
# 66      66                                     dti:<=1.4     -0.044335
# 67      67                                   dti:1.4-3.5     -0.143463
# 68      68                                   dti:3.5-7.7     -0.188775
# 69      69                                  dti:7.7-10.5     -0.128609
# 70      70                                 dti:10.5-16.1     -0.052064
# 71      71                                 dti:16.1-20.3      0.048309
# 72      72                                 dti:20.3-21.7      0.054907
# 73      73                                 dti:21.7-22.4      0.097961
# 74      74                                   dti:22.4-35      0.138627
# 75      75                mths_since_last_delinq:Missing     -0.054715
# 76      76                   mths_since_last_delinq:4-30     -0.081572
# 77      77                  mths_since_last_delinq:31-56     -0.129250
# 78      78                   mths_since_last_delinq:>=57     -0.082053
# 79      79                mths_since_last_record:Missing     -0.104441
# 80      80                   mths_since_last_record:3-20     -0.221704
# 81      81                  mths_since_last_record:21-31     -0.155567
# 82      82                  mths_since_last_record:32-80     -0.279192
# 83      83                  mths_since_last_record:81-86      0.069623
# 84      84                    mths_since_last_record:>86     -0.019178
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values
# 0              NaN
# 1     5.228543e-36
# 2     1.444867e-48
# 3     5.078288e-35
# 4     2.345055e-21
# 5     4.065619e-12
# 6     3.842305e-03
# 7     2.957628e-06
# 8     4.055983e-17
# 9     2.297686e-01
# 10    1.580057e-02
# 11    8.261890e-03
# 12    2.328402e-03
# 13    1.367798e-03
# 14    1.244014e-09
# 15    6.103984e-04
# 16    2.309147e-12
# 17    3.382059e-07
# 18    7.516273e-18
# 19    1.967860e-19
# 20    1.465993e-25
# 21    5.825112e-23
# 22    5.521459e-09
# 23    4.033018e-01
# 24    1.675732e-26
# 25    2.714947e-14
# 26    6.923052e-12
# 27    2.049396e-17
# 28    3.416099e-05
# 29    2.451245e-08
# 30    1.340395e-04
# 31    4.149322e-11
# 32    2.413170e-05
# 33    3.329767e-03
# 34    8.428200e-12
# 35   4.771942e-179
# 36   3.275977e-148
# 37   5.639309e-122
# 38    1.945723e-85
# 39    1.242287e-38
# 40    1.238312e-07
# 41    9.489601e-04
# 42    1.060389e-30
# 43    6.349835e-35
# 44    2.871065e-16
# 45    1.281457e-04
# 46    6.120157e-02
# 47    1.914854e-01
# 48    1.067262e-02
# 49    3.611655e-06
# 50    5.335146e-05
# 51    5.150038e-10
# 52    7.236550e-07
# 53    1.862575e-03
# 54    6.396446e-02
# 55    1.051865e-01
# 56    9.001588e-01
# 57    2.864444e-02
# 58    1.563247e-04
# 59    4.210979e-08
# 60    1.375474e-12
# 61    1.855527e-17
# 62    5.535245e-18
# 63    2.003728e-25
# 64    6.624766e-28
# 65    3.943226e-26
# 66    3.520154e-03
# 67    5.977388e-07
# 68    2.028858e-09
# 69    4.657782e-07
# 70    8.369092e-05
# 71    2.027027e-02
# 72    4.074991e-02
# 73    1.531979e-01
# 74    3.595815e-01
# 75    2.824465e-02
# 76    6.877103e-03
# 77    4.209465e-04
# 78    9.611698e-03
# 79    3.769795e-05
# 80    1.932350e-04
# 81    7.901537e-04
# 82    1.516691e-09
# 83    5.936840e-02
# 84    2.650404e-03
# 85             NaN
# 86             NaN
# 87             NaN
# 88             NaN
# 89             NaN
# 90             NaN
# 91             NaN
# 92             NaN
# 93             NaN
# 94             NaN
# 95             NaN
# 96             NaN
# 97             NaN
# 98             NaN
# 99             NaN
# 100            NaN
# 101            NaN

# %%
df_scorecard['Original feature name'] = df_scorecard['Feature name'].str.split(':').str[0]
# We create a new column, called 'Original feature name', which contains the value of the 'Feature name' column,
# up to the column symbol.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept      0.285875
# 1        1                                       grade:A     -0.919195
# 2        2                                       grade:B     -0.682024
# 3        3                                       grade:C     -0.487724
# 4        4                                       grade:D     -0.301685
# 5        5                                       grade:E     -0.148087
# 6        6                                       grade:F      0.043608
# 7        7                            home_ownership:OWN     -0.080723
# 8        8                       home_ownership:MORTGAGE     -0.104898
# 9        9                              addr_state:NM_VA     -0.048291
# 10      10                                 addr_state:NY     -0.068487
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC     -0.070422
# 12      12                                 addr_state:CA     -0.076130
# 13      13                        addr_state:UT_KY_AZ_NJ     -0.090757
# 14      14                     addr_state:AR_MI_PA_OH_MN     -0.144463
# 15      15                     addr_state:RI_MA_DE_SD_IN     -0.108486
# 16      16                           addr_state:GA_WA_OR     -0.196587
# 17      17                              addr_state:WI_MT     -0.238044
# 18      18                                 addr_state:TX     -0.235403
# 19      19                              addr_state:IL_CT     -0.276107
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS     -0.346185
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID     -0.532143
# 22      22              verification_status:Not Verified     -0.085403
# 23      23           verification_status:Source Verified      0.009270
# 24      24                           purpose:credit_card     -0.278639
# 25      25                    purpose:debt_consolidation     -0.178795
# 26      26                    purpose:oth__med__vacation     -0.200195
# 27      27           purpose:major_purch__car__home_impr     -0.253347
# 28      28                         initial_list_status:w     -0.052342
# 29      29                                       term:36     -0.070272
# 30      30                                  emp_length:1     -0.097493
# 31      31                                emp_length:2-4     -0.129849
# 32      32                                emp_length:5-6     -0.096627
# 33      33                                emp_length:7-9     -0.067485
# 34      34                                 emp_length:10     -0.132494
# 35      35                        mths_since_issue_d:<38     -1.138992
# 36      36                      mths_since_issue_d:38-39     -0.912410
# 37      37                      mths_since_issue_d:40-41     -0.823573
# 38      38                      mths_since_issue_d:42-48     -0.625728
# 39      39                      mths_since_issue_d:49-52     -0.472437
# 40      40                      mths_since_issue_d:53-64     -0.225799
# 41      41                      mths_since_issue_d:65-84      0.030679
# 42      42                               int_rate:<9.548     -0.947824
# 43      43                         int_rate:9.548-12.025     -0.607130
# 44      44                         int_rate:12.025-15.74     -0.353838
# 45      45                         int_rate:15.74-20.281     -0.148072
# 46      46           mths_since_earliest_cr_line:141-164     -0.055357
# 47      47           mths_since_earliest_cr_line:165-247     -0.037786
# 48      48           mths_since_earliest_cr_line:248-270     -0.081576
# 49      49           mths_since_earliest_cr_line:271-352     -0.123195
# 50      50              mths_since_earliest_cr_line:>352     -0.122856
# 51      51                              inq_last_6mths:0     -0.267295
# 52      52                            inq_last_6mths:1-2     -0.124940
# 53      53                            inq_last_6mths:3-6      0.083733
# 54      54                            acc_now_delinq:>=1     -0.143598
# 55      55                            annual_inc:20K-30K      0.196162
# 56      56                            annual_inc:30K-40K      0.135578
# 57      57                            annual_inc:40K-50K      0.044705
# 58      58                            annual_inc:50K-60K     -0.021923
# 59      59                            annual_inc:60K-70K     -0.092344
# 60      60                            annual_inc:70K-80K     -0.167604
# 61      61                            annual_inc:80K-90K     -0.237180
# 62      62                           annual_inc:90K-100K     -0.264362
# 63      63                          annual_inc:100K-120K     -0.340167
# 64      64                          annual_inc:120K-140K     -0.403604
# 65      65                              annual_inc:>140K     -0.376088
# 66      66                                     dti:<=1.4     -0.044335
# 67      67                                   dti:1.4-3.5     -0.143463
# 68      68                                   dti:3.5-7.7     -0.188775
# 69      69                                  dti:7.7-10.5     -0.128609
# 70      70                                 dti:10.5-16.1     -0.052064
# 71      71                                 dti:16.1-20.3      0.048309
# 72      72                                 dti:20.3-21.7      0.054907
# 73      73                                 dti:21.7-22.4      0.097961
# 74      74                                   dti:22.4-35      0.138627
# 75      75                mths_since_last_delinq:Missing     -0.054715
# 76      76                   mths_since_last_delinq:4-30     -0.081572
# 77      77                  mths_since_last_delinq:31-56     -0.129250
# 78      78                   mths_since_last_delinq:>=57     -0.082053
# 79      79                mths_since_last_record:Missing     -0.104441
# 80      80                   mths_since_last_record:3-20     -0.221704
# 81      81                  mths_since_last_record:21-31     -0.155567
# 82      82                  mths_since_last_record:32-80     -0.279192
# 83      83                  mths_since_last_record:81-86      0.069623
# 84      84                    mths_since_last_record:>86     -0.019178
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name
# 0              NaN                    Intercept
# 1     5.228543e-36                        grade
# 2     1.444867e-48                        grade
# 3     5.078288e-35                        grade
# 4     2.345055e-21                        grade
# 5     4.065619e-12                        grade
# 6     3.842305e-03                        grade
# 7     2.957628e-06               home_ownership
# 8     4.055983e-17               home_ownership
# 9     2.297686e-01                   addr_state
# 10    1.580057e-02                   addr_state
# 11    8.261890e-03                   addr_state
# 12    2.328402e-03                   addr_state
# 13    1.367798e-03                   addr_state
# 14    1.244014e-09                   addr_state
# 15    6.103984e-04                   addr_state
# 16    2.309147e-12                   addr_state
# 17    3.382059e-07                   addr_state
# 18    7.516273e-18                   addr_state
# 19    1.967860e-19                   addr_state
# 20    1.465993e-25                   addr_state
# 21    5.825112e-23                   addr_state
# 22    5.521459e-09          verification_status
# 23    4.033018e-01          verification_status
# 24    1.675732e-26                      purpose
# 25    2.714947e-14                      purpose
# 26    6.923052e-12                      purpose
# 27    2.049396e-17                      purpose
# 28    3.416099e-05          initial_list_status
# 29    2.451245e-08                         term
# 30    1.340395e-04                   emp_length
# 31    4.149322e-11                   emp_length
# 32    2.413170e-05                   emp_length
# 33    3.329767e-03                   emp_length
# 34    8.428200e-12                   emp_length
# 35   4.771942e-179           mths_since_issue_d
# 36   3.275977e-148           mths_since_issue_d
# 37   5.639309e-122           mths_since_issue_d
# 38    1.945723e-85           mths_since_issue_d
# 39    1.242287e-38           mths_since_issue_d
# 40    1.238312e-07           mths_since_issue_d
# 41    9.489601e-04           mths_since_issue_d
# 42    1.060389e-30                     int_rate
# 43    6.349835e-35                     int_rate
# 44    2.871065e-16                     int_rate
# 45    1.281457e-04                     int_rate
# 46    6.120157e-02  mths_since_earliest_cr_line
# 47    1.914854e-01  mths_since_earliest_cr_line
# 48    1.067262e-02  mths_since_earliest_cr_line
# 49    3.611655e-06  mths_since_earliest_cr_line
# 50    5.335146e-05  mths_since_earliest_cr_line
# 51    5.150038e-10               inq_last_6mths
# 52    7.236550e-07               inq_last_6mths
# 53    1.862575e-03               inq_last_6mths
# 54    6.396446e-02               acc_now_delinq
# 55    1.051865e-01                   annual_inc
# 56    9.001588e-01                   annual_inc
# 57    2.864444e-02                   annual_inc
# 58    1.563247e-04                   annual_inc
# 59    4.210979e-08                   annual_inc
# 60    1.375474e-12                   annual_inc
# 61    1.855527e-17                   annual_inc
# 62    5.535245e-18                   annual_inc
# 63    2.003728e-25                   annual_inc
# 64    6.624766e-28                   annual_inc
# 65    3.943226e-26                   annual_inc
# 66    3.520154e-03                          dti
# 67    5.977388e-07                          dti
# 68    2.028858e-09                          dti
# 69    4.657782e-07                          dti
# 70    8.369092e-05                          dti
# 71    2.027027e-02                          dti
# 72    4.074991e-02                          dti
# 73    1.531979e-01                          dti
# 74    3.595815e-01                          dti
# 75    2.824465e-02       mths_since_last_delinq
# 76    6.877103e-03       mths_since_last_delinq
# 77    4.209465e-04       mths_since_last_delinq
# 78    9.611698e-03       mths_since_last_delinq
# 79    3.769795e-05       mths_since_last_record
# 80    1.932350e-04       mths_since_last_record
# 81    7.901537e-04       mths_since_last_record
# 82    1.516691e-09       mths_since_last_record
# 83    5.936840e-02       mths_since_last_record
# 84    2.650404e-03       mths_since_last_record
# 85             NaN                        grade
# 86             NaN               home_ownership
# 87             NaN                   addr_state
# 88             NaN          verification_status
# 89             NaN                      purpose
# 90             NaN          initial_list_status
# 91             NaN                         term
# 92             NaN                   emp_length
# 93             NaN           mths_since_issue_d
# 94             NaN                     int_rate
# 95             NaN  mths_since_earliest_cr_line
# 96             NaN               inq_last_6mths
# 97             NaN               acc_now_delinq
# 98             NaN                   annual_inc
# 99             NaN                          dti
# 100            NaN       mths_since_last_delinq
# 101            NaN       mths_since_last_record

# %%
min_score = 300
max_score = 850

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].max()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their minimum.
# Out:
# Original feature name
# Intercept                      0.285875
# acc_now_delinq                 0.000000
# addr_state                     0.000000
# annual_inc                     0.196162
# dti                            0.138627
# emp_length                     0.000000
# grade                          0.043608
# home_ownership                 0.000000
# initial_list_status            0.000000
# inq_last_6mths                 0.083733
# int_rate                       0.000000
# mths_since_earliest_cr_line    0.000000
# mths_since_issue_d             0.030679
# mths_since_last_delinq         0.000000
# mths_since_last_record         0.069623
# purpose                        0.000000
# term                           0.000000
# verification_status            0.009270
# Name: Coefficients, dtype: float64

# %%
min_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].max().sum()
# Up to the 'min()' method everything is the same as in te line above.
# Then, we aggregate further and sum all the minimum values.
min_sum_coef
# Out:
# 0.8575771789836678

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].min()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their maximum.
# Out:
# Original feature name
# Intercept                      0.285875
# acc_now_delinq                -0.143598
# addr_state                    -0.532143
# annual_inc                    -0.403604
# dti                           -0.188775
# emp_length                    -0.132494
# grade                         -0.919195
# home_ownership                -0.104898
# initial_list_status           -0.052342
# inq_last_6mths                -0.267295
# int_rate                      -0.947824
# mths_since_earliest_cr_line   -0.123195
# mths_since_issue_d            -1.138992
# mths_since_last_delinq        -0.129250
# mths_since_last_record        -0.279192
# purpose                       -0.278639
# term                          -0.070272
# verification_status           -0.085403
# Name: Coefficients, dtype: float64

# %%
max_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].min().sum()
# Up to the 'min()' method everything is the same as in te line above.
# Then, we aggregate further and sum all the maximum values.
max_sum_coef
# Out:
# -5.511235521537467

# %%
df_scorecard['Score - Calculation'] = df_scorecard['Coefficients'] * (max_score - min_score) / (max_sum_coef - min_sum_coef)
# We multiply the value of the 'Coefficients' column by the ration of the differences between
# maximum score and minimum score and maximum sum of coefficients and minimum sum of cefficients.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept      0.285875
# 1        1                                       grade:A     -0.919195
# 2        2                                       grade:B     -0.682024
# 3        3                                       grade:C     -0.487724
# 4        4                                       grade:D     -0.301685
# 5        5                                       grade:E     -0.148087
# 6        6                                       grade:F      0.043608
# 7        7                            home_ownership:OWN     -0.080723
# 8        8                       home_ownership:MORTGAGE     -0.104898
# 9        9                              addr_state:NM_VA     -0.048291
# 10      10                                 addr_state:NY     -0.068487
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC     -0.070422
# 12      12                                 addr_state:CA     -0.076130
# 13      13                        addr_state:UT_KY_AZ_NJ     -0.090757
# 14      14                     addr_state:AR_MI_PA_OH_MN     -0.144463
# 15      15                     addr_state:RI_MA_DE_SD_IN     -0.108486
# 16      16                           addr_state:GA_WA_OR     -0.196587
# 17      17                              addr_state:WI_MT     -0.238044
# 18      18                                 addr_state:TX     -0.235403
# 19      19                              addr_state:IL_CT     -0.276107
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS     -0.346185
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID     -0.532143
# 22      22              verification_status:Not Verified     -0.085403
# 23      23           verification_status:Source Verified      0.009270
# 24      24                           purpose:credit_card     -0.278639
# 25      25                    purpose:debt_consolidation     -0.178795
# 26      26                    purpose:oth__med__vacation     -0.200195
# 27      27           purpose:major_purch__car__home_impr     -0.253347
# 28      28                         initial_list_status:w     -0.052342
# 29      29                                       term:36     -0.070272
# 30      30                                  emp_length:1     -0.097493
# 31      31                                emp_length:2-4     -0.129849
# 32      32                                emp_length:5-6     -0.096627
# 33      33                                emp_length:7-9     -0.067485
# 34      34                                 emp_length:10     -0.132494
# 35      35                        mths_since_issue_d:<38     -1.138992
# 36      36                      mths_since_issue_d:38-39     -0.912410
# 37      37                      mths_since_issue_d:40-41     -0.823573
# 38      38                      mths_since_issue_d:42-48     -0.625728
# 39      39                      mths_since_issue_d:49-52     -0.472437
# 40      40                      mths_since_issue_d:53-64     -0.225799
# 41      41                      mths_since_issue_d:65-84      0.030679
# 42      42                               int_rate:<9.548     -0.947824
# 43      43                         int_rate:9.548-12.025     -0.607130
# 44      44                         int_rate:12.025-15.74     -0.353838
# 45      45                         int_rate:15.74-20.281     -0.148072
# 46      46           mths_since_earliest_cr_line:141-164     -0.055357
# 47      47           mths_since_earliest_cr_line:165-247     -0.037786
# 48      48           mths_since_earliest_cr_line:248-270     -0.081576
# 49      49           mths_since_earliest_cr_line:271-352     -0.123195
# 50      50              mths_since_earliest_cr_line:>352     -0.122856
# 51      51                              inq_last_6mths:0     -0.267295
# 52      52                            inq_last_6mths:1-2     -0.124940
# 53      53                            inq_last_6mths:3-6      0.083733
# 54      54                            acc_now_delinq:>=1     -0.143598
# 55      55                            annual_inc:20K-30K      0.196162
# 56      56                            annual_inc:30K-40K      0.135578
# 57      57                            annual_inc:40K-50K      0.044705
# 58      58                            annual_inc:50K-60K     -0.021923
# 59      59                            annual_inc:60K-70K     -0.092344
# 60      60                            annual_inc:70K-80K     -0.167604
# 61      61                            annual_inc:80K-90K     -0.237180
# 62      62                           annual_inc:90K-100K     -0.264362
# 63      63                          annual_inc:100K-120K     -0.340167
# 64      64                          annual_inc:120K-140K     -0.403604
# 65      65                              annual_inc:>140K     -0.376088
# 66      66                                     dti:<=1.4     -0.044335
# 67      67                                   dti:1.4-3.5     -0.143463
# 68      68                                   dti:3.5-7.7     -0.188775
# 69      69                                  dti:7.7-10.5     -0.128609
# 70      70                                 dti:10.5-16.1     -0.052064
# 71      71                                 dti:16.1-20.3      0.048309
# 72      72                                 dti:20.3-21.7      0.054907
# 73      73                                 dti:21.7-22.4      0.097961
# 74      74                                   dti:22.4-35      0.138627
# 75      75                mths_since_last_delinq:Missing     -0.054715
# 76      76                   mths_since_last_delinq:4-30     -0.081572
# 77      77                  mths_since_last_delinq:31-56     -0.129250
# 78      78                   mths_since_last_delinq:>=57     -0.082053
# 79      79                mths_since_last_record:Missing     -0.104441
# 80      80                   mths_since_last_record:3-20     -0.221704
# 81      81                  mths_since_last_record:21-31     -0.155567
# 82      82                  mths_since_last_record:32-80     -0.279192
# 83      83                  mths_since_last_record:81-86      0.069623
# 84      84                    mths_since_last_record:>86     -0.019178
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation
# 0              NaN                    Intercept           -24.687709
# 1     5.228543e-36                        grade            79.380181
# 2     1.444867e-48                        grade            58.898431
# 3     5.078288e-35                        grade            42.119006
# 4     2.345055e-21                        grade            26.052998
# 5     4.065619e-12                        grade            12.788518
# 6     3.842305e-03                        grade            -3.765882
# 7     2.957628e-06               home_ownership             6.971098
# 8     4.055983e-17               home_ownership             9.058840
# 9     2.297686e-01                   addr_state             4.170351
# 10    1.580057e-02                   addr_state             5.914413
# 11    8.261890e-03                   addr_state             6.081528
# 12    2.328402e-03                   addr_state             6.574489
# 13    1.367798e-03                   addr_state             7.837641
# 14    1.244014e-09                   addr_state            12.475578
# 15    6.103984e-04                   addr_state             9.368647
# 16    2.309147e-12                   addr_state            16.976940
# 17    3.382059e-07                   addr_state            20.557119
# 18    7.516273e-18                   addr_state            20.328970
# 19    1.967860e-19                   addr_state            23.844140
# 20    1.465993e-25                   addr_state            29.895995
# 21    5.825112e-23                   addr_state            45.954989
# 22    5.521459e-09          verification_status             7.375277
# 23    4.033018e-01          verification_status            -0.800570
# 24    1.675732e-26                      purpose            24.062758
# 25    2.714947e-14                      purpose            15.440427
# 26    6.923052e-12                      purpose            17.288486
# 27    2.049396e-17                      purpose            21.878639
# 28    3.416099e-05          initial_list_status             4.520166
# 29    2.451245e-08                         term             6.068533
# 30    1.340395e-04                   emp_length             8.419358
# 31    4.149322e-11                   emp_length            11.213556
# 32    2.413170e-05                   emp_length             8.344534
# 33    3.329767e-03                   emp_length             5.827866
# 34    8.428200e-12                   emp_length            11.441931
# 35   4.771942e-179           mths_since_issue_d            98.361460
# 36   3.275977e-148           mths_since_issue_d            78.794186
# 37   5.639309e-122           mths_since_issue_d            71.122370
# 38    1.945723e-85           mths_since_issue_d            54.036851
# 39    1.242287e-38           mths_since_issue_d            40.798883
# 40    1.238312e-07           mths_since_issue_d            19.499612
# 41    9.489601e-04           mths_since_issue_d            -2.649426
# 42    1.060389e-30                     int_rate            81.852495
# 43    6.349835e-35                     int_rate            52.430746
# 44    2.871065e-16                     int_rate            30.556839
# 45    1.281457e-04                     int_rate            12.787256
# 46    6.120157e-02  mths_since_earliest_cr_line             4.780551
# 47    1.914854e-01  mths_since_earliest_cr_line             3.263130
# 48    1.067262e-02  mths_since_earliest_cr_line             7.044809
# 49    3.611655e-06  mths_since_earliest_cr_line            10.638893
# 50    5.335146e-05  mths_since_earliest_cr_line            10.609609
# 51    5.150038e-10               inq_last_6mths            23.083144
# 52    7.236550e-07               inq_last_6mths            10.789650
# 53    1.862575e-03               inq_last_6mths            -7.231016
# 54    6.396446e-02               acc_now_delinq            12.400878
# 55    1.051865e-01                   annual_inc           -16.940227
# 56    9.001588e-01                   annual_inc           -11.708252
# 57    2.864444e-02                   annual_inc            -3.860632
# 58    1.563247e-04                   annual_inc             1.893233
# 59    4.210979e-08                   annual_inc             7.974672
# 60    1.375474e-12                   annual_inc            14.473964
# 61    1.855527e-17                   annual_inc            20.482487
# 62    5.535245e-18                   annual_inc            22.829880
# 63    2.003728e-25                   annual_inc            29.376283
# 64    6.624766e-28                   annual_inc            34.854595
# 65    3.943226e-26                   annual_inc            32.478371
# 66    3.520154e-03                          dti             3.828712
# 67    5.977388e-07                          dti            12.389236
# 68    2.028858e-09                          dti            16.302323
# 69    4.657782e-07                          dti            11.106490
# 70    8.369092e-05                          dti             4.496126
# 71    2.027027e-02                          dti            -4.171885
# 72    4.074991e-02                          dti            -4.741658
# 73    1.531979e-01                          dti            -8.459742
# 74    3.595815e-01                          dti           -11.971590
# 75    2.824465e-02       mths_since_last_delinq             4.725099
# 76    6.877103e-03       mths_since_last_delinq             7.044459
# 77    4.209465e-04       mths_since_last_delinq            11.161797
# 78    9.611698e-03       mths_since_last_delinq             7.085922
# 79    3.769795e-05       mths_since_last_record             9.019380
# 80    1.932350e-04       mths_since_last_record            19.145973
# 81    7.901537e-04       mths_since_last_record            13.434466
# 82    1.516691e-09       mths_since_last_record            24.110518
# 83    5.936840e-02       mths_since_last_record            -6.012510
# 84    2.650404e-03       mths_since_last_record             1.656150
# 85             NaN                        grade            -0.000000
# 86             NaN               home_ownership            -0.000000
# 87             NaN                   addr_state            -0.000000
# 88             NaN          verification_status            -0.000000
# 89             NaN                      purpose            -0.000000
# 90             NaN          initial_list_status            -0.000000
# 91             NaN                         term            -0.000000
# 92             NaN                   emp_length            -0.000000
# 93             NaN           mths_since_issue_d            -0.000000
# 94             NaN                     int_rate            -0.000000
# 95             NaN  mths_since_earliest_cr_line            -0.000000
# 96             NaN               inq_last_6mths            -0.000000
# 97             NaN               acc_now_delinq            -0.000000
# 98             NaN                   annual_inc            -0.000000
# 99             NaN                          dti            -0.000000
# 100            NaN       mths_since_last_delinq            -0.000000
# 101            NaN       mths_since_last_record            -0.000000

# %%
df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
# We divide the difference of the value of the 'Coefficients' column and the minimum sum of coefficients by
# the difference of the maximum sum of coefficients and the minimum sum of coefficients.
# Then, we multiply that by the difference between the maximum score and the minimum score.
# Then, we add minimum score. 
df_scorecard
# Out:
# C:\Users\Pierre Pro\AppData\Local\Temp\ipykernel_10000\1410049194.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
# C:\Users\Pierre Pro\AppData\Local\Temp\ipykernel_10000\1410049194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept      0.285875
# 1        1                                       grade:A     -0.919195
# 2        2                                       grade:B     -0.682024
# 3        3                                       grade:C     -0.487724
# 4        4                                       grade:D     -0.301685
# 5        5                                       grade:E     -0.148087
# 6        6                                       grade:F      0.043608
# 7        7                            home_ownership:OWN     -0.080723
# 8        8                       home_ownership:MORTGAGE     -0.104898
# 9        9                              addr_state:NM_VA     -0.048291
# 10      10                                 addr_state:NY     -0.068487
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC     -0.070422
# 12      12                                 addr_state:CA     -0.076130
# 13      13                        addr_state:UT_KY_AZ_NJ     -0.090757
# 14      14                     addr_state:AR_MI_PA_OH_MN     -0.144463
# 15      15                     addr_state:RI_MA_DE_SD_IN     -0.108486
# 16      16                           addr_state:GA_WA_OR     -0.196587
# 17      17                              addr_state:WI_MT     -0.238044
# 18      18                                 addr_state:TX     -0.235403
# 19      19                              addr_state:IL_CT     -0.276107
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS     -0.346185
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID     -0.532143
# 22      22              verification_status:Not Verified     -0.085403
# 23      23           verification_status:Source Verified      0.009270
# 24      24                           purpose:credit_card     -0.278639
# 25      25                    purpose:debt_consolidation     -0.178795
# 26      26                    purpose:oth__med__vacation     -0.200195
# 27      27           purpose:major_purch__car__home_impr     -0.253347
# 28      28                         initial_list_status:w     -0.052342
# 29      29                                       term:36     -0.070272
# 30      30                                  emp_length:1     -0.097493
# 31      31                                emp_length:2-4     -0.129849
# 32      32                                emp_length:5-6     -0.096627
# 33      33                                emp_length:7-9     -0.067485
# 34      34                                 emp_length:10     -0.132494
# 35      35                        mths_since_issue_d:<38     -1.138992
# 36      36                      mths_since_issue_d:38-39     -0.912410
# 37      37                      mths_since_issue_d:40-41     -0.823573
# 38      38                      mths_since_issue_d:42-48     -0.625728
# 39      39                      mths_since_issue_d:49-52     -0.472437
# 40      40                      mths_since_issue_d:53-64     -0.225799
# 41      41                      mths_since_issue_d:65-84      0.030679
# 42      42                               int_rate:<9.548     -0.947824
# 43      43                         int_rate:9.548-12.025     -0.607130
# 44      44                         int_rate:12.025-15.74     -0.353838
# 45      45                         int_rate:15.74-20.281     -0.148072
# 46      46           mths_since_earliest_cr_line:141-164     -0.055357
# 47      47           mths_since_earliest_cr_line:165-247     -0.037786
# 48      48           mths_since_earliest_cr_line:248-270     -0.081576
# 49      49           mths_since_earliest_cr_line:271-352     -0.123195
# 50      50              mths_since_earliest_cr_line:>352     -0.122856
# 51      51                              inq_last_6mths:0     -0.267295
# 52      52                            inq_last_6mths:1-2     -0.124940
# 53      53                            inq_last_6mths:3-6      0.083733
# 54      54                            acc_now_delinq:>=1     -0.143598
# 55      55                            annual_inc:20K-30K      0.196162
# 56      56                            annual_inc:30K-40K      0.135578
# 57      57                            annual_inc:40K-50K      0.044705
# 58      58                            annual_inc:50K-60K     -0.021923
# 59      59                            annual_inc:60K-70K     -0.092344
# 60      60                            annual_inc:70K-80K     -0.167604
# 61      61                            annual_inc:80K-90K     -0.237180
# 62      62                           annual_inc:90K-100K     -0.264362
# 63      63                          annual_inc:100K-120K     -0.340167
# 64      64                          annual_inc:120K-140K     -0.403604
# 65      65                              annual_inc:>140K     -0.376088
# 66      66                                     dti:<=1.4     -0.044335
# 67      67                                   dti:1.4-3.5     -0.143463
# 68      68                                   dti:3.5-7.7     -0.188775
# 69      69                                  dti:7.7-10.5     -0.128609
# 70      70                                 dti:10.5-16.1     -0.052064
# 71      71                                 dti:16.1-20.3      0.048309
# 72      72                                 dti:20.3-21.7      0.054907
# 73      73                                 dti:21.7-22.4      0.097961
# 74      74                                   dti:22.4-35      0.138627
# 75      75                mths_since_last_delinq:Missing     -0.054715
# 76      76                   mths_since_last_delinq:4-30     -0.081572
# 77      77                  mths_since_last_delinq:31-56     -0.129250
# 78      78                   mths_since_last_delinq:>=57     -0.082053
# 79      79                mths_since_last_record:Missing     -0.104441
# 80      80                   mths_since_last_record:3-20     -0.221704
# 81      81                  mths_since_last_record:21-31     -0.155567
# 82      82                  mths_since_last_record:32-80     -0.279192
# 83      83                  mths_since_last_record:81-86      0.069623
# 84      84                    mths_since_last_record:>86     -0.019178
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation
# 0              NaN                    Intercept           349.371220
# 1     5.228543e-36                        grade            79.380181
# 2     1.444867e-48                        grade            58.898431
# 3     5.078288e-35                        grade            42.119006
# 4     2.345055e-21                        grade            26.052998
# 5     4.065619e-12                        grade            12.788518
# 6     3.842305e-03                        grade            -3.765882
# 7     2.957628e-06               home_ownership             6.971098
# 8     4.055983e-17               home_ownership             9.058840
# 9     2.297686e-01                   addr_state             4.170351
# 10    1.580057e-02                   addr_state             5.914413
# 11    8.261890e-03                   addr_state             6.081528
# 12    2.328402e-03                   addr_state             6.574489
# 13    1.367798e-03                   addr_state             7.837641
# 14    1.244014e-09                   addr_state            12.475578
# 15    6.103984e-04                   addr_state             9.368647
# 16    2.309147e-12                   addr_state            16.976940
# 17    3.382059e-07                   addr_state            20.557119
# 18    7.516273e-18                   addr_state            20.328970
# 19    1.967860e-19                   addr_state            23.844140
# 20    1.465993e-25                   addr_state            29.895995
# 21    5.825112e-23                   addr_state            45.954989
# 22    5.521459e-09          verification_status             7.375277
# 23    4.033018e-01          verification_status            -0.800570
# 24    1.675732e-26                      purpose            24.062758
# 25    2.714947e-14                      purpose            15.440427
# 26    6.923052e-12                      purpose            17.288486
# 27    2.049396e-17                      purpose            21.878639
# 28    3.416099e-05          initial_list_status             4.520166
# 29    2.451245e-08                         term             6.068533
# 30    1.340395e-04                   emp_length             8.419358
# 31    4.149322e-11                   emp_length            11.213556
# 32    2.413170e-05                   emp_length             8.344534
# 33    3.329767e-03                   emp_length             5.827866
# 34    8.428200e-12                   emp_length            11.441931
# 35   4.771942e-179           mths_since_issue_d            98.361460
# 36   3.275977e-148           mths_since_issue_d            78.794186
# 37   5.639309e-122           mths_since_issue_d            71.122370
# 38    1.945723e-85           mths_since_issue_d            54.036851
# 39    1.242287e-38           mths_since_issue_d            40.798883
# 40    1.238312e-07           mths_since_issue_d            19.499612
# 41    9.489601e-04           mths_since_issue_d            -2.649426
# 42    1.060389e-30                     int_rate            81.852495
# 43    6.349835e-35                     int_rate            52.430746
# 44    2.871065e-16                     int_rate            30.556839
# 45    1.281457e-04                     int_rate            12.787256
# 46    6.120157e-02  mths_since_earliest_cr_line             4.780551
# 47    1.914854e-01  mths_since_earliest_cr_line             3.263130
# 48    1.067262e-02  mths_since_earliest_cr_line             7.044809
# 49    3.611655e-06  mths_since_earliest_cr_line            10.638893
# 50    5.335146e-05  mths_since_earliest_cr_line            10.609609
# 51    5.150038e-10               inq_last_6mths            23.083144
# 52    7.236550e-07               inq_last_6mths            10.789650
# 53    1.862575e-03               inq_last_6mths            -7.231016
# 54    6.396446e-02               acc_now_delinq            12.400878
# 55    1.051865e-01                   annual_inc           -16.940227
# 56    9.001588e-01                   annual_inc           -11.708252
# 57    2.864444e-02                   annual_inc            -3.860632
# 58    1.563247e-04                   annual_inc             1.893233
# 59    4.210979e-08                   annual_inc             7.974672
# 60    1.375474e-12                   annual_inc            14.473964
# 61    1.855527e-17                   annual_inc            20.482487
# 62    5.535245e-18                   annual_inc            22.829880
# 63    2.003728e-25                   annual_inc            29.376283
# 64    6.624766e-28                   annual_inc            34.854595
# 65    3.943226e-26                   annual_inc            32.478371
# 66    3.520154e-03                          dti             3.828712
# 67    5.977388e-07                          dti            12.389236
# 68    2.028858e-09                          dti            16.302323
# 69    4.657782e-07                          dti            11.106490
# 70    8.369092e-05                          dti             4.496126
# 71    2.027027e-02                          dti            -4.171885
# 72    4.074991e-02                          dti            -4.741658
# 73    1.531979e-01                          dti            -8.459742
# 74    3.595815e-01                          dti           -11.971590
# 75    2.824465e-02       mths_since_last_delinq             4.725099
# 76    6.877103e-03       mths_since_last_delinq             7.044459
# 77    4.209465e-04       mths_since_last_delinq            11.161797
# 78    9.611698e-03       mths_since_last_delinq             7.085922
# 79    3.769795e-05       mths_since_last_record             9.019380
# 80    1.932350e-04       mths_since_last_record            19.145973
# 81    7.901537e-04       mths_since_last_record            13.434466
# 82    1.516691e-09       mths_since_last_record            24.110518
# 83    5.936840e-02       mths_since_last_record            -6.012510
# 84    2.650404e-03       mths_since_last_record             1.656150
# 85             NaN                        grade            -0.000000
# 86             NaN               home_ownership            -0.000000
# 87             NaN                   addr_state            -0.000000
# 88             NaN          verification_status            -0.000000
# 89             NaN                      purpose            -0.000000
# 90             NaN          initial_list_status            -0.000000
# 91             NaN                         term            -0.000000
# 92             NaN                   emp_length            -0.000000
# 93             NaN           mths_since_issue_d            -0.000000
# 94             NaN                     int_rate            -0.000000
# 95             NaN  mths_since_earliest_cr_line            -0.000000
# 96             NaN               inq_last_6mths            -0.000000
# 97             NaN               acc_now_delinq            -0.000000
# 98             NaN                   annual_inc            -0.000000
# 99             NaN                          dti            -0.000000
# 100            NaN       mths_since_last_delinq            -0.000000
# 101            NaN       mths_since_last_record            -0.000000

# %%
df_scorecard['Score - Preliminary'] = df_scorecard['Score - Calculation'].round()
# We round the values of the 'Score - Calculation' column.
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept      0.285875
# 1        1                                       grade:A     -0.919195
# 2        2                                       grade:B     -0.682024
# 3        3                                       grade:C     -0.487724
# 4        4                                       grade:D     -0.301685
# 5        5                                       grade:E     -0.148087
# 6        6                                       grade:F      0.043608
# 7        7                            home_ownership:OWN     -0.080723
# 8        8                       home_ownership:MORTGAGE     -0.104898
# 9        9                              addr_state:NM_VA     -0.048291
# 10      10                                 addr_state:NY     -0.068487
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC     -0.070422
# 12      12                                 addr_state:CA     -0.076130
# 13      13                        addr_state:UT_KY_AZ_NJ     -0.090757
# 14      14                     addr_state:AR_MI_PA_OH_MN     -0.144463
# 15      15                     addr_state:RI_MA_DE_SD_IN     -0.108486
# 16      16                           addr_state:GA_WA_OR     -0.196587
# 17      17                              addr_state:WI_MT     -0.238044
# 18      18                                 addr_state:TX     -0.235403
# 19      19                              addr_state:IL_CT     -0.276107
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS     -0.346185
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID     -0.532143
# 22      22              verification_status:Not Verified     -0.085403
# 23      23           verification_status:Source Verified      0.009270
# 24      24                           purpose:credit_card     -0.278639
# 25      25                    purpose:debt_consolidation     -0.178795
# 26      26                    purpose:oth__med__vacation     -0.200195
# 27      27           purpose:major_purch__car__home_impr     -0.253347
# 28      28                         initial_list_status:w     -0.052342
# 29      29                                       term:36     -0.070272
# 30      30                                  emp_length:1     -0.097493
# 31      31                                emp_length:2-4     -0.129849
# 32      32                                emp_length:5-6     -0.096627
# 33      33                                emp_length:7-9     -0.067485
# 34      34                                 emp_length:10     -0.132494
# 35      35                        mths_since_issue_d:<38     -1.138992
# 36      36                      mths_since_issue_d:38-39     -0.912410
# 37      37                      mths_since_issue_d:40-41     -0.823573
# 38      38                      mths_since_issue_d:42-48     -0.625728
# 39      39                      mths_since_issue_d:49-52     -0.472437
# 40      40                      mths_since_issue_d:53-64     -0.225799
# 41      41                      mths_since_issue_d:65-84      0.030679
# 42      42                               int_rate:<9.548     -0.947824
# 43      43                         int_rate:9.548-12.025     -0.607130
# 44      44                         int_rate:12.025-15.74     -0.353838
# 45      45                         int_rate:15.74-20.281     -0.148072
# 46      46           mths_since_earliest_cr_line:141-164     -0.055357
# 47      47           mths_since_earliest_cr_line:165-247     -0.037786
# 48      48           mths_since_earliest_cr_line:248-270     -0.081576
# 49      49           mths_since_earliest_cr_line:271-352     -0.123195
# 50      50              mths_since_earliest_cr_line:>352     -0.122856
# 51      51                              inq_last_6mths:0     -0.267295
# 52      52                            inq_last_6mths:1-2     -0.124940
# 53      53                            inq_last_6mths:3-6      0.083733
# 54      54                            acc_now_delinq:>=1     -0.143598
# 55      55                            annual_inc:20K-30K      0.196162
# 56      56                            annual_inc:30K-40K      0.135578
# 57      57                            annual_inc:40K-50K      0.044705
# 58      58                            annual_inc:50K-60K     -0.021923
# 59      59                            annual_inc:60K-70K     -0.092344
# 60      60                            annual_inc:70K-80K     -0.167604
# 61      61                            annual_inc:80K-90K     -0.237180
# 62      62                           annual_inc:90K-100K     -0.264362
# 63      63                          annual_inc:100K-120K     -0.340167
# 64      64                          annual_inc:120K-140K     -0.403604
# 65      65                              annual_inc:>140K     -0.376088
# 66      66                                     dti:<=1.4     -0.044335
# 67      67                                   dti:1.4-3.5     -0.143463
# 68      68                                   dti:3.5-7.7     -0.188775
# 69      69                                  dti:7.7-10.5     -0.128609
# 70      70                                 dti:10.5-16.1     -0.052064
# 71      71                                 dti:16.1-20.3      0.048309
# 72      72                                 dti:20.3-21.7      0.054907
# 73      73                                 dti:21.7-22.4      0.097961
# 74      74                                   dti:22.4-35      0.138627
# 75      75                mths_since_last_delinq:Missing     -0.054715
# 76      76                   mths_since_last_delinq:4-30     -0.081572
# 77      77                  mths_since_last_delinq:31-56     -0.129250
# 78      78                   mths_since_last_delinq:>=57     -0.082053
# 79      79                mths_since_last_record:Missing     -0.104441
# 80      80                   mths_since_last_record:3-20     -0.221704
# 81      81                  mths_since_last_record:21-31     -0.155567
# 82      82                  mths_since_last_record:32-80     -0.279192
# 83      83                  mths_since_last_record:81-86      0.069623
# 84      84                    mths_since_last_record:>86     -0.019178
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           349.371220
# 1     5.228543e-36                        grade            79.380181
# 2     1.444867e-48                        grade            58.898431
# 3     5.078288e-35                        grade            42.119006
# 4     2.345055e-21                        grade            26.052998
# 5     4.065619e-12                        grade            12.788518
# 6     3.842305e-03                        grade            -3.765882
# 7     2.957628e-06               home_ownership             6.971098
# 8     4.055983e-17               home_ownership             9.058840
# 9     2.297686e-01                   addr_state             4.170351
# 10    1.580057e-02                   addr_state             5.914413
# 11    8.261890e-03                   addr_state             6.081528
# 12    2.328402e-03                   addr_state             6.574489
# 13    1.367798e-03                   addr_state             7.837641
# 14    1.244014e-09                   addr_state            12.475578
# 15    6.103984e-04                   addr_state             9.368647
# 16    2.309147e-12                   addr_state            16.976940
# 17    3.382059e-07                   addr_state            20.557119
# 18    7.516273e-18                   addr_state            20.328970
# 19    1.967860e-19                   addr_state            23.844140
# 20    1.465993e-25                   addr_state            29.895995
# 21    5.825112e-23                   addr_state            45.954989
# 22    5.521459e-09          verification_status             7.375277
# 23    4.033018e-01          verification_status            -0.800570
# 24    1.675732e-26                      purpose            24.062758
# 25    2.714947e-14                      purpose            15.440427
# 26    6.923052e-12                      purpose            17.288486
# 27    2.049396e-17                      purpose            21.878639
# 28    3.416099e-05          initial_list_status             4.520166
# 29    2.451245e-08                         term             6.068533
# 30    1.340395e-04                   emp_length             8.419358
# 31    4.149322e-11                   emp_length            11.213556
# 32    2.413170e-05                   emp_length             8.344534
# 33    3.329767e-03                   emp_length             5.827866
# 34    8.428200e-12                   emp_length            11.441931
# 35   4.771942e-179           mths_since_issue_d            98.361460
# 36   3.275977e-148           mths_since_issue_d            78.794186
# 37   5.639309e-122           mths_since_issue_d            71.122370
# 38    1.945723e-85           mths_since_issue_d            54.036851
# 39    1.242287e-38           mths_since_issue_d            40.798883
# 40    1.238312e-07           mths_since_issue_d            19.499612
# 41    9.489601e-04           mths_since_issue_d            -2.649426
# 42    1.060389e-30                     int_rate            81.852495
# 43    6.349835e-35                     int_rate            52.430746
# 44    2.871065e-16                     int_rate            30.556839
# 45    1.281457e-04                     int_rate            12.787256
# 46    6.120157e-02  mths_since_earliest_cr_line             4.780551
# 47    1.914854e-01  mths_since_earliest_cr_line             3.263130
# 48    1.067262e-02  mths_since_earliest_cr_line             7.044809
# 49    3.611655e-06  mths_since_earliest_cr_line            10.638893
# 50    5.335146e-05  mths_since_earliest_cr_line            10.609609
# 51    5.150038e-10               inq_last_6mths            23.083144
# 52    7.236550e-07               inq_last_6mths            10.789650
# 53    1.862575e-03               inq_last_6mths            -7.231016
# 54    6.396446e-02               acc_now_delinq            12.400878
# 55    1.051865e-01                   annual_inc           -16.940227
# 56    9.001588e-01                   annual_inc           -11.708252
# 57    2.864444e-02                   annual_inc            -3.860632
# 58    1.563247e-04                   annual_inc             1.893233
# 59    4.210979e-08                   annual_inc             7.974672
# 60    1.375474e-12                   annual_inc            14.473964
# 61    1.855527e-17                   annual_inc            20.482487
# 62    5.535245e-18                   annual_inc            22.829880
# 63    2.003728e-25                   annual_inc            29.376283
# 64    6.624766e-28                   annual_inc            34.854595
# 65    3.943226e-26                   annual_inc            32.478371
# 66    3.520154e-03                          dti             3.828712
# 67    5.977388e-07                          dti            12.389236
# 68    2.028858e-09                          dti            16.302323
# 69    4.657782e-07                          dti            11.106490
# 70    8.369092e-05                          dti             4.496126
# 71    2.027027e-02                          dti            -4.171885
# 72    4.074991e-02                          dti            -4.741658
# 73    1.531979e-01                          dti            -8.459742
# 74    3.595815e-01                          dti           -11.971590
# 75    2.824465e-02       mths_since_last_delinq             4.725099
# 76    6.877103e-03       mths_since_last_delinq             7.044459
# 77    4.209465e-04       mths_since_last_delinq            11.161797
# 78    9.611698e-03       mths_since_last_delinq             7.085922
# 79    3.769795e-05       mths_since_last_record             9.019380
# 80    1.932350e-04       mths_since_last_record            19.145973
# 81    7.901537e-04       mths_since_last_record            13.434466
# 82    1.516691e-09       mths_since_last_record            24.110518
# 83    5.936840e-02       mths_since_last_record            -6.012510
# 84    2.650404e-03       mths_since_last_record             1.656150
# 85             NaN                        grade            -0.000000
# 86             NaN               home_ownership            -0.000000
# 87             NaN                   addr_state            -0.000000
# 88             NaN          verification_status            -0.000000
# 89             NaN                      purpose            -0.000000
# 90             NaN          initial_list_status            -0.000000
# 91             NaN                         term            -0.000000
# 92             NaN                   emp_length            -0.000000
# 93             NaN           mths_since_issue_d            -0.000000
# 94             NaN                     int_rate            -0.000000
# 95             NaN  mths_since_earliest_cr_line            -0.000000
# 96             NaN               inq_last_6mths            -0.000000
# 97             NaN               acc_now_delinq            -0.000000
# 98             NaN                   annual_inc            -0.000000
# 99             NaN                          dti            -0.000000
# 100            NaN       mths_since_last_delinq            -0.000000
# 101            NaN       mths_since_last_record            -0.000000
#
#      Score - Preliminary
# 0                  349.0
# 1                   79.0
# 2                   59.0
# 3                   42.0
# 4                   26.0
# 5                   13.0
# 6                   -4.0
# 7                    7.0
# 8                    9.0
# 9                    4.0
# 10                   6.0
# 11                   6.0
# 12                   7.0
# 13                   8.0
# 14                  12.0
# 15                   9.0
# 16                  17.0
# 17                  21.0
# 18                  20.0
# 19                  24.0
# 20                  30.0
# 21                  46.0
# 22                   7.0
# 23                  -1.0
# 24                  24.0
# 25                  15.0
# 26                  17.0
# 27                  22.0
# 28                   5.0
# 29                   6.0
# 30                   8.0
# 31                  11.0
# 32                   8.0
# 33                   6.0
# 34                  11.0
# 35                  98.0
# 36                  79.0
# 37                  71.0
# 38                  54.0
# 39                  41.0
# 40                  19.0
# 41                  -3.0
# 42                  82.0
# 43                  52.0
# 44                  31.0
# 45                  13.0
# 46                   5.0
# 47                   3.0
# 48                   7.0
# 49                  11.0
# 50                  11.0
# 51                  23.0
# 52                  11.0
# 53                  -7.0
# 54                  12.0
# 55                 -17.0
# 56                 -12.0
# 57                  -4.0
# 58                   2.0
# 59                   8.0
# 60                  14.0
# 61                  20.0
# 62                  23.0
# 63                  29.0
# 64                  35.0
# 65                  32.0
# 66                   4.0
# 67                  12.0
# 68                  16.0
# 69                  11.0
# 70                   4.0
# 71                  -4.0
# 72                  -5.0
# 73                  -8.0
# 74                 -12.0
# 75                   5.0
# 76                   7.0
# 77                  11.0
# 78                   7.0
# 79                   9.0
# 80                  19.0
# 81                  13.0
# 82                  24.0
# 83                  -6.0
# 84                   2.0
# 85                  -0.0
# 86                  -0.0
# 87                  -0.0
# 88                  -0.0
# 89                  -0.0
# 90                  -0.0
# 91                  -0.0
# 92                  -0.0
# 93                  -0.0
# 94                  -0.0
# 95                  -0.0
# 96                  -0.0
# 97                  -0.0
# 98                  -0.0
# 99                  -0.0
# 100                 -0.0
# 101                 -0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].min().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their minimum.
# Sums all minimum values.
min_sum_score_prel
# Out:
# 299.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].max().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their maximum.
# Sums all maximum values.
max_sum_score_prel
# Out:
# 848.0

# %%
# One has to be subtracted from the maximum score for one original variable. Which one? We'll evaluate based on differences.

# %%
df_scorecard['Difference'] = df_scorecard['Score - Preliminary'] - df_scorecard['Score - Calculation']
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept      0.285875
# 1        1                                       grade:A     -0.919195
# 2        2                                       grade:B     -0.682024
# 3        3                                       grade:C     -0.487724
# 4        4                                       grade:D     -0.301685
# 5        5                                       grade:E     -0.148087
# 6        6                                       grade:F      0.043608
# 7        7                            home_ownership:OWN     -0.080723
# 8        8                       home_ownership:MORTGAGE     -0.104898
# 9        9                              addr_state:NM_VA     -0.048291
# 10      10                                 addr_state:NY     -0.068487
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC     -0.070422
# 12      12                                 addr_state:CA     -0.076130
# 13      13                        addr_state:UT_KY_AZ_NJ     -0.090757
# 14      14                     addr_state:AR_MI_PA_OH_MN     -0.144463
# 15      15                     addr_state:RI_MA_DE_SD_IN     -0.108486
# 16      16                           addr_state:GA_WA_OR     -0.196587
# 17      17                              addr_state:WI_MT     -0.238044
# 18      18                                 addr_state:TX     -0.235403
# 19      19                              addr_state:IL_CT     -0.276107
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS     -0.346185
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID     -0.532143
# 22      22              verification_status:Not Verified     -0.085403
# 23      23           verification_status:Source Verified      0.009270
# 24      24                           purpose:credit_card     -0.278639
# 25      25                    purpose:debt_consolidation     -0.178795
# 26      26                    purpose:oth__med__vacation     -0.200195
# 27      27           purpose:major_purch__car__home_impr     -0.253347
# 28      28                         initial_list_status:w     -0.052342
# 29      29                                       term:36     -0.070272
# 30      30                                  emp_length:1     -0.097493
# 31      31                                emp_length:2-4     -0.129849
# 32      32                                emp_length:5-6     -0.096627
# 33      33                                emp_length:7-9     -0.067485
# 34      34                                 emp_length:10     -0.132494
# 35      35                        mths_since_issue_d:<38     -1.138992
# 36      36                      mths_since_issue_d:38-39     -0.912410
# 37      37                      mths_since_issue_d:40-41     -0.823573
# 38      38                      mths_since_issue_d:42-48     -0.625728
# 39      39                      mths_since_issue_d:49-52     -0.472437
# 40      40                      mths_since_issue_d:53-64     -0.225799
# 41      41                      mths_since_issue_d:65-84      0.030679
# 42      42                               int_rate:<9.548     -0.947824
# 43      43                         int_rate:9.548-12.025     -0.607130
# 44      44                         int_rate:12.025-15.74     -0.353838
# 45      45                         int_rate:15.74-20.281     -0.148072
# 46      46           mths_since_earliest_cr_line:141-164     -0.055357
# 47      47           mths_since_earliest_cr_line:165-247     -0.037786
# 48      48           mths_since_earliest_cr_line:248-270     -0.081576
# 49      49           mths_since_earliest_cr_line:271-352     -0.123195
# 50      50              mths_since_earliest_cr_line:>352     -0.122856
# 51      51                              inq_last_6mths:0     -0.267295
# 52      52                            inq_last_6mths:1-2     -0.124940
# 53      53                            inq_last_6mths:3-6      0.083733
# 54      54                            acc_now_delinq:>=1     -0.143598
# 55      55                            annual_inc:20K-30K      0.196162
# 56      56                            annual_inc:30K-40K      0.135578
# 57      57                            annual_inc:40K-50K      0.044705
# 58      58                            annual_inc:50K-60K     -0.021923
# 59      59                            annual_inc:60K-70K     -0.092344
# 60      60                            annual_inc:70K-80K     -0.167604
# 61      61                            annual_inc:80K-90K     -0.237180
# 62      62                           annual_inc:90K-100K     -0.264362
# 63      63                          annual_inc:100K-120K     -0.340167
# 64      64                          annual_inc:120K-140K     -0.403604
# 65      65                              annual_inc:>140K     -0.376088
# 66      66                                     dti:<=1.4     -0.044335
# 67      67                                   dti:1.4-3.5     -0.143463
# 68      68                                   dti:3.5-7.7     -0.188775
# 69      69                                  dti:7.7-10.5     -0.128609
# 70      70                                 dti:10.5-16.1     -0.052064
# 71      71                                 dti:16.1-20.3      0.048309
# 72      72                                 dti:20.3-21.7      0.054907
# 73      73                                 dti:21.7-22.4      0.097961
# 74      74                                   dti:22.4-35      0.138627
# 75      75                mths_since_last_delinq:Missing     -0.054715
# 76      76                   mths_since_last_delinq:4-30     -0.081572
# 77      77                  mths_since_last_delinq:31-56     -0.129250
# 78      78                   mths_since_last_delinq:>=57     -0.082053
# 79      79                mths_since_last_record:Missing     -0.104441
# 80      80                   mths_since_last_record:3-20     -0.221704
# 81      81                  mths_since_last_record:21-31     -0.155567
# 82      82                  mths_since_last_record:32-80     -0.279192
# 83      83                  mths_since_last_record:81-86      0.069623
# 84      84                    mths_since_last_record:>86     -0.019178
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           349.371220
# 1     5.228543e-36                        grade            79.380181
# 2     1.444867e-48                        grade            58.898431
# 3     5.078288e-35                        grade            42.119006
# 4     2.345055e-21                        grade            26.052998
# 5     4.065619e-12                        grade            12.788518
# 6     3.842305e-03                        grade            -3.765882
# 7     2.957628e-06               home_ownership             6.971098
# 8     4.055983e-17               home_ownership             9.058840
# 9     2.297686e-01                   addr_state             4.170351
# 10    1.580057e-02                   addr_state             5.914413
# 11    8.261890e-03                   addr_state             6.081528
# 12    2.328402e-03                   addr_state             6.574489
# 13    1.367798e-03                   addr_state             7.837641
# 14    1.244014e-09                   addr_state            12.475578
# 15    6.103984e-04                   addr_state             9.368647
# 16    2.309147e-12                   addr_state            16.976940
# 17    3.382059e-07                   addr_state            20.557119
# 18    7.516273e-18                   addr_state            20.328970
# 19    1.967860e-19                   addr_state            23.844140
# 20    1.465993e-25                   addr_state            29.895995
# 21    5.825112e-23                   addr_state            45.954989
# 22    5.521459e-09          verification_status             7.375277
# 23    4.033018e-01          verification_status            -0.800570
# 24    1.675732e-26                      purpose            24.062758
# 25    2.714947e-14                      purpose            15.440427
# 26    6.923052e-12                      purpose            17.288486
# 27    2.049396e-17                      purpose            21.878639
# 28    3.416099e-05          initial_list_status             4.520166
# 29    2.451245e-08                         term             6.068533
# 30    1.340395e-04                   emp_length             8.419358
# 31    4.149322e-11                   emp_length            11.213556
# 32    2.413170e-05                   emp_length             8.344534
# 33    3.329767e-03                   emp_length             5.827866
# 34    8.428200e-12                   emp_length            11.441931
# 35   4.771942e-179           mths_since_issue_d            98.361460
# 36   3.275977e-148           mths_since_issue_d            78.794186
# 37   5.639309e-122           mths_since_issue_d            71.122370
# 38    1.945723e-85           mths_since_issue_d            54.036851
# 39    1.242287e-38           mths_since_issue_d            40.798883
# 40    1.238312e-07           mths_since_issue_d            19.499612
# 41    9.489601e-04           mths_since_issue_d            -2.649426
# 42    1.060389e-30                     int_rate            81.852495
# 43    6.349835e-35                     int_rate            52.430746
# 44    2.871065e-16                     int_rate            30.556839
# 45    1.281457e-04                     int_rate            12.787256
# 46    6.120157e-02  mths_since_earliest_cr_line             4.780551
# 47    1.914854e-01  mths_since_earliest_cr_line             3.263130
# 48    1.067262e-02  mths_since_earliest_cr_line             7.044809
# 49    3.611655e-06  mths_since_earliest_cr_line            10.638893
# 50    5.335146e-05  mths_since_earliest_cr_line            10.609609
# 51    5.150038e-10               inq_last_6mths            23.083144
# 52    7.236550e-07               inq_last_6mths            10.789650
# 53    1.862575e-03               inq_last_6mths            -7.231016
# 54    6.396446e-02               acc_now_delinq            12.400878
# 55    1.051865e-01                   annual_inc           -16.940227
# 56    9.001588e-01                   annual_inc           -11.708252
# 57    2.864444e-02                   annual_inc            -3.860632
# 58    1.563247e-04                   annual_inc             1.893233
# 59    4.210979e-08                   annual_inc             7.974672
# 60    1.375474e-12                   annual_inc            14.473964
# 61    1.855527e-17                   annual_inc            20.482487
# 62    5.535245e-18                   annual_inc            22.829880
# 63    2.003728e-25                   annual_inc            29.376283
# 64    6.624766e-28                   annual_inc            34.854595
# 65    3.943226e-26                   annual_inc            32.478371
# 66    3.520154e-03                          dti             3.828712
# 67    5.977388e-07                          dti            12.389236
# 68    2.028858e-09                          dti            16.302323
# 69    4.657782e-07                          dti            11.106490
# 70    8.369092e-05                          dti             4.496126
# 71    2.027027e-02                          dti            -4.171885
# 72    4.074991e-02                          dti            -4.741658
# 73    1.531979e-01                          dti            -8.459742
# 74    3.595815e-01                          dti           -11.971590
# 75    2.824465e-02       mths_since_last_delinq             4.725099
# 76    6.877103e-03       mths_since_last_delinq             7.044459
# 77    4.209465e-04       mths_since_last_delinq            11.161797
# 78    9.611698e-03       mths_since_last_delinq             7.085922
# 79    3.769795e-05       mths_since_last_record             9.019380
# 80    1.932350e-04       mths_since_last_record            19.145973
# 81    7.901537e-04       mths_since_last_record            13.434466
# 82    1.516691e-09       mths_since_last_record            24.110518
# 83    5.936840e-02       mths_since_last_record            -6.012510
# 84    2.650404e-03       mths_since_last_record             1.656150
# 85             NaN                        grade            -0.000000
# 86             NaN               home_ownership            -0.000000
# 87             NaN                   addr_state            -0.000000
# 88             NaN          verification_status            -0.000000
# 89             NaN                      purpose            -0.000000
# 90             NaN          initial_list_status            -0.000000
# 91             NaN                         term            -0.000000
# 92             NaN                   emp_length            -0.000000
# 93             NaN           mths_since_issue_d            -0.000000
# 94             NaN                     int_rate            -0.000000
# 95             NaN  mths_since_earliest_cr_line            -0.000000
# 96             NaN               inq_last_6mths            -0.000000
# 97             NaN               acc_now_delinq            -0.000000
# 98             NaN                   annual_inc            -0.000000
# 99             NaN                          dti            -0.000000
# 100            NaN       mths_since_last_delinq            -0.000000
# 101            NaN       mths_since_last_record            -0.000000
#
#      Score - Preliminary  Difference
# 0                  349.0   -0.371220
# 1                   79.0   -0.380181
# 2                   59.0    0.101569
# 3                   42.0   -0.119006
# 4                   26.0   -0.052998
# 5                   13.0    0.211482
# 6                   -4.0   -0.234118
# 7                    7.0    0.028902
# 8                    9.0   -0.058840
# 9                    4.0   -0.170351
# 10                   6.0    0.085587
# 11                   6.0   -0.081528
# 12                   7.0    0.425511
# 13                   8.0    0.162359
# 14                  12.0   -0.475578
# 15                   9.0   -0.368647
# 16                  17.0    0.023060
# 17                  21.0    0.442881
# 18                  20.0   -0.328970
# 19                  24.0    0.155860
# 20                  30.0    0.104005
# 21                  46.0    0.045011
# 22                   7.0   -0.375277
# 23                  -1.0   -0.199430
# 24                  24.0   -0.062758
# 25                  15.0   -0.440427
# 26                  17.0   -0.288486
# 27                  22.0    0.121361
# 28                   5.0    0.479834
# 29                   6.0   -0.068533
# 30                   8.0   -0.419358
# 31                  11.0   -0.213556
# 32                   8.0   -0.344534
# 33                   6.0    0.172134
# 34                  11.0   -0.441931
# 35                  98.0   -0.361460
# 36                  79.0    0.205814
# 37                  71.0   -0.122370
# 38                  54.0   -0.036851
# 39                  41.0    0.201117
# 40                  19.0   -0.499612
# 41                  -3.0   -0.350574
# 42                  82.0    0.147505
# 43                  52.0   -0.430746
# 44                  31.0    0.443161
# 45                  13.0    0.212744
# 46                   5.0    0.219449
# 47                   3.0   -0.263130
# 48                   7.0   -0.044809
# 49                  11.0    0.361107
# 50                  11.0    0.390391
# 51                  23.0   -0.083144
# 52                  11.0    0.210350
# 53                  -7.0    0.231016
# 54                  12.0   -0.400878
# 55                 -17.0   -0.059773
# 56                 -12.0   -0.291748
# 57                  -4.0   -0.139368
# 58                   2.0    0.106767
# 59                   8.0    0.025328
# 60                  14.0   -0.473964
# 61                  20.0   -0.482487
# 62                  23.0    0.170120
# 63                  29.0   -0.376283
# 64                  35.0    0.145405
# 65                  32.0   -0.478371
# 66                   4.0    0.171288
# 67                  12.0   -0.389236
# 68                  16.0   -0.302323
# 69                  11.0   -0.106490
# 70                   4.0   -0.496126
# 71                  -4.0    0.171885
# 72                  -5.0   -0.258342
# 73                  -8.0    0.459742
# 74                 -12.0   -0.028410
# 75                   5.0    0.274901
# 76                   7.0   -0.044459
# 77                  11.0   -0.161797
# 78                   7.0   -0.085922
# 79                   9.0   -0.019380
# 80                  19.0   -0.145973
# 81                  13.0   -0.434466
# 82                  24.0   -0.110518
# 83                  -6.0    0.012510
# 84                   2.0    0.343850
# 85                  -0.0    0.000000
# 86                  -0.0    0.000000
# 87                  -0.0    0.000000
# 88                  -0.0    0.000000
# 89                  -0.0    0.000000
# 90                  -0.0    0.000000
# 91                  -0.0    0.000000
# 92                  -0.0    0.000000
# 93                  -0.0    0.000000
# 94                  -0.0    0.000000
# 95                  -0.0    0.000000
# 96                  -0.0    0.000000
# 97                  -0.0    0.000000
# 98                  -0.0    0.000000
# 99                  -0.0    0.000000
# 100                 -0.0    0.000000
# 101                 -0.0    0.000000

# %%
df_scorecard['Score - Final'] = df_scorecard['Score - Preliminary']
df_scorecard['Score - Final'][77] = 15
df_scorecard['Score - Final'][77] = 15
df_scorecard
# Out:
# C:\Users\Pierre Pro\AppData\Local\Temp\ipykernel_10000\2019451084.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_scorecard['Score - Final'][77] = 15
# C:\Users\Pierre Pro\AppData\Local\Temp\ipykernel_10000\2019451084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Final'][77] = 15
# C:\Users\Pierre Pro\AppData\Local\Temp\ipykernel_10000\2019451084.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_scorecard['Score - Final'][77] = 15
# C:\Users\Pierre Pro\AppData\Local\Temp\ipykernel_10000\2019451084.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Final'][77] = 15
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept      0.285875
# 1        1                                       grade:A     -0.919195
# 2        2                                       grade:B     -0.682024
# 3        3                                       grade:C     -0.487724
# 4        4                                       grade:D     -0.301685
# 5        5                                       grade:E     -0.148087
# 6        6                                       grade:F      0.043608
# 7        7                            home_ownership:OWN     -0.080723
# 8        8                       home_ownership:MORTGAGE     -0.104898
# 9        9                              addr_state:NM_VA     -0.048291
# 10      10                                 addr_state:NY     -0.068487
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC     -0.070422
# 12      12                                 addr_state:CA     -0.076130
# 13      13                        addr_state:UT_KY_AZ_NJ     -0.090757
# 14      14                     addr_state:AR_MI_PA_OH_MN     -0.144463
# 15      15                     addr_state:RI_MA_DE_SD_IN     -0.108486
# 16      16                           addr_state:GA_WA_OR     -0.196587
# 17      17                              addr_state:WI_MT     -0.238044
# 18      18                                 addr_state:TX     -0.235403
# 19      19                              addr_state:IL_CT     -0.276107
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS     -0.346185
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID     -0.532143
# 22      22              verification_status:Not Verified     -0.085403
# 23      23           verification_status:Source Verified      0.009270
# 24      24                           purpose:credit_card     -0.278639
# 25      25                    purpose:debt_consolidation     -0.178795
# 26      26                    purpose:oth__med__vacation     -0.200195
# 27      27           purpose:major_purch__car__home_impr     -0.253347
# 28      28                         initial_list_status:w     -0.052342
# 29      29                                       term:36     -0.070272
# 30      30                                  emp_length:1     -0.097493
# 31      31                                emp_length:2-4     -0.129849
# 32      32                                emp_length:5-6     -0.096627
# 33      33                                emp_length:7-9     -0.067485
# 34      34                                 emp_length:10     -0.132494
# 35      35                        mths_since_issue_d:<38     -1.138992
# 36      36                      mths_since_issue_d:38-39     -0.912410
# 37      37                      mths_since_issue_d:40-41     -0.823573
# 38      38                      mths_since_issue_d:42-48     -0.625728
# 39      39                      mths_since_issue_d:49-52     -0.472437
# 40      40                      mths_since_issue_d:53-64     -0.225799
# 41      41                      mths_since_issue_d:65-84      0.030679
# 42      42                               int_rate:<9.548     -0.947824
# 43      43                         int_rate:9.548-12.025     -0.607130
# 44      44                         int_rate:12.025-15.74     -0.353838
# 45      45                         int_rate:15.74-20.281     -0.148072
# 46      46           mths_since_earliest_cr_line:141-164     -0.055357
# 47      47           mths_since_earliest_cr_line:165-247     -0.037786
# 48      48           mths_since_earliest_cr_line:248-270     -0.081576
# 49      49           mths_since_earliest_cr_line:271-352     -0.123195
# 50      50              mths_since_earliest_cr_line:>352     -0.122856
# 51      51                              inq_last_6mths:0     -0.267295
# 52      52                            inq_last_6mths:1-2     -0.124940
# 53      53                            inq_last_6mths:3-6      0.083733
# 54      54                            acc_now_delinq:>=1     -0.143598
# 55      55                            annual_inc:20K-30K      0.196162
# 56      56                            annual_inc:30K-40K      0.135578
# 57      57                            annual_inc:40K-50K      0.044705
# 58      58                            annual_inc:50K-60K     -0.021923
# 59      59                            annual_inc:60K-70K     -0.092344
# 60      60                            annual_inc:70K-80K     -0.167604
# 61      61                            annual_inc:80K-90K     -0.237180
# 62      62                           annual_inc:90K-100K     -0.264362
# 63      63                          annual_inc:100K-120K     -0.340167
# 64      64                          annual_inc:120K-140K     -0.403604
# 65      65                              annual_inc:>140K     -0.376088
# 66      66                                     dti:<=1.4     -0.044335
# 67      67                                   dti:1.4-3.5     -0.143463
# 68      68                                   dti:3.5-7.7     -0.188775
# 69      69                                  dti:7.7-10.5     -0.128609
# 70      70                                 dti:10.5-16.1     -0.052064
# 71      71                                 dti:16.1-20.3      0.048309
# 72      72                                 dti:20.3-21.7      0.054907
# 73      73                                 dti:21.7-22.4      0.097961
# 74      74                                   dti:22.4-35      0.138627
# 75      75                mths_since_last_delinq:Missing     -0.054715
# 76      76                   mths_since_last_delinq:4-30     -0.081572
# 77      77                  mths_since_last_delinq:31-56     -0.129250
# 78      78                   mths_since_last_delinq:>=57     -0.082053
# 79      79                mths_since_last_record:Missing     -0.104441
# 80      80                   mths_since_last_record:3-20     -0.221704
# 81      81                  mths_since_last_record:21-31     -0.155567
# 82      82                  mths_since_last_record:32-80     -0.279192
# 83      83                  mths_since_last_record:81-86      0.069623
# 84      84                    mths_since_last_record:>86     -0.019178
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           349.371220
# 1     5.228543e-36                        grade            79.380181
# 2     1.444867e-48                        grade            58.898431
# 3     5.078288e-35                        grade            42.119006
# 4     2.345055e-21                        grade            26.052998
# 5     4.065619e-12                        grade            12.788518
# 6     3.842305e-03                        grade            -3.765882
# 7     2.957628e-06               home_ownership             6.971098
# 8     4.055983e-17               home_ownership             9.058840
# 9     2.297686e-01                   addr_state             4.170351
# 10    1.580057e-02                   addr_state             5.914413
# 11    8.261890e-03                   addr_state             6.081528
# 12    2.328402e-03                   addr_state             6.574489
# 13    1.367798e-03                   addr_state             7.837641
# 14    1.244014e-09                   addr_state            12.475578
# 15    6.103984e-04                   addr_state             9.368647
# 16    2.309147e-12                   addr_state            16.976940
# 17    3.382059e-07                   addr_state            20.557119
# 18    7.516273e-18                   addr_state            20.328970
# 19    1.967860e-19                   addr_state            23.844140
# 20    1.465993e-25                   addr_state            29.895995
# 21    5.825112e-23                   addr_state            45.954989
# 22    5.521459e-09          verification_status             7.375277
# 23    4.033018e-01          verification_status            -0.800570
# 24    1.675732e-26                      purpose            24.062758
# 25    2.714947e-14                      purpose            15.440427
# 26    6.923052e-12                      purpose            17.288486
# 27    2.049396e-17                      purpose            21.878639
# 28    3.416099e-05          initial_list_status             4.520166
# 29    2.451245e-08                         term             6.068533
# 30    1.340395e-04                   emp_length             8.419358
# 31    4.149322e-11                   emp_length            11.213556
# 32    2.413170e-05                   emp_length             8.344534
# 33    3.329767e-03                   emp_length             5.827866
# 34    8.428200e-12                   emp_length            11.441931
# 35   4.771942e-179           mths_since_issue_d            98.361460
# 36   3.275977e-148           mths_since_issue_d            78.794186
# 37   5.639309e-122           mths_since_issue_d            71.122370
# 38    1.945723e-85           mths_since_issue_d            54.036851
# 39    1.242287e-38           mths_since_issue_d            40.798883
# 40    1.238312e-07           mths_since_issue_d            19.499612
# 41    9.489601e-04           mths_since_issue_d            -2.649426
# 42    1.060389e-30                     int_rate            81.852495
# 43    6.349835e-35                     int_rate            52.430746
# 44    2.871065e-16                     int_rate            30.556839
# 45    1.281457e-04                     int_rate            12.787256
# 46    6.120157e-02  mths_since_earliest_cr_line             4.780551
# 47    1.914854e-01  mths_since_earliest_cr_line             3.263130
# 48    1.067262e-02  mths_since_earliest_cr_line             7.044809
# 49    3.611655e-06  mths_since_earliest_cr_line            10.638893
# 50    5.335146e-05  mths_since_earliest_cr_line            10.609609
# 51    5.150038e-10               inq_last_6mths            23.083144
# 52    7.236550e-07               inq_last_6mths            10.789650
# 53    1.862575e-03               inq_last_6mths            -7.231016
# 54    6.396446e-02               acc_now_delinq            12.400878
# 55    1.051865e-01                   annual_inc           -16.940227
# 56    9.001588e-01                   annual_inc           -11.708252
# 57    2.864444e-02                   annual_inc            -3.860632
# 58    1.563247e-04                   annual_inc             1.893233
# 59    4.210979e-08                   annual_inc             7.974672
# 60    1.375474e-12                   annual_inc            14.473964
# 61    1.855527e-17                   annual_inc            20.482487
# 62    5.535245e-18                   annual_inc            22.829880
# 63    2.003728e-25                   annual_inc            29.376283
# 64    6.624766e-28                   annual_inc            34.854595
# 65    3.943226e-26                   annual_inc            32.478371
# 66    3.520154e-03                          dti             3.828712
# 67    5.977388e-07                          dti            12.389236
# 68    2.028858e-09                          dti            16.302323
# 69    4.657782e-07                          dti            11.106490
# 70    8.369092e-05                          dti             4.496126
# 71    2.027027e-02                          dti            -4.171885
# 72    4.074991e-02                          dti            -4.741658
# 73    1.531979e-01                          dti            -8.459742
# 74    3.595815e-01                          dti           -11.971590
# 75    2.824465e-02       mths_since_last_delinq             4.725099
# 76    6.877103e-03       mths_since_last_delinq             7.044459
# 77    4.209465e-04       mths_since_last_delinq            11.161797
# 78    9.611698e-03       mths_since_last_delinq             7.085922
# 79    3.769795e-05       mths_since_last_record             9.019380
# 80    1.932350e-04       mths_since_last_record            19.145973
# 81    7.901537e-04       mths_since_last_record            13.434466
# 82    1.516691e-09       mths_since_last_record            24.110518
# 83    5.936840e-02       mths_since_last_record            -6.012510
# 84    2.650404e-03       mths_since_last_record             1.656150
# 85             NaN                        grade            -0.000000
# 86             NaN               home_ownership            -0.000000
# 87             NaN                   addr_state            -0.000000
# 88             NaN          verification_status            -0.000000
# 89             NaN                      purpose            -0.000000
# 90             NaN          initial_list_status            -0.000000
# 91             NaN                         term            -0.000000
# 92             NaN                   emp_length            -0.000000
# 93             NaN           mths_since_issue_d            -0.000000
# 94             NaN                     int_rate            -0.000000
# 95             NaN  mths_since_earliest_cr_line            -0.000000
# 96             NaN               inq_last_6mths            -0.000000
# 97             NaN               acc_now_delinq            -0.000000
# 98             NaN                   annual_inc            -0.000000
# 99             NaN                          dti            -0.000000
# 100            NaN       mths_since_last_delinq            -0.000000
# 101            NaN       mths_since_last_record            -0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                
# 85                  -0.0    0.000000           -0.0
# 86                  -0.0    0.000000           -0.0
# 87                  -0.0    0.000000           -0.0
# 88                  -0.0    0.000000           -0.0
# 89                  -0.0    0.000000           -0.0
# 90                  -0.0    0.000000           -0.0
# 91                  -0.0    0.000000           -0.0
# 92                  -0.0    0.000000           -0.0
# 93                  -0.0    0.000000           -0.0
# 94                  -0.0    0.000000           -0.0
# 95                  -0.0    0.000000           -0.0
# 96                  -0.0    0.000000           -0.0
# 97                  -0.0    0.000000           -0.0
# 98                  -0.0    0.000000           -0.0
# 99                  -0.0    0.000000           -0.0
# 100                 -0.0    0.000000           -0.0
# 101                 -0.0    0.000000           -0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].min().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their minimum.
# Sums all minimum values.
min_sum_score_prel
# Out:
# 299.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].max().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their maximum.
# Sums all maximum values.
max_sum_score_prel
# Out:
# 852.0

# %% [markdown]
# ### Caclulating Credit Score

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>86
# 362514                             0                           0
# 288564                             0                           0
# 213591                             0                           0
# 263083                             0                           0
# 165001                             0                           0

# %%
df_scorecard
# Out:
#      index                                  Feature name  Coefficients  \
# 0        0                                     Intercept      0.285875
# 1        1                                       grade:A     -0.919195
# 2        2                                       grade:B     -0.682024
# 3        3                                       grade:C     -0.487724
# 4        4                                       grade:D     -0.301685
# 5        5                                       grade:E     -0.148087
# 6        6                                       grade:F      0.043608
# 7        7                            home_ownership:OWN     -0.080723
# 8        8                       home_ownership:MORTGAGE     -0.104898
# 9        9                              addr_state:NM_VA     -0.048291
# 10      10                                 addr_state:NY     -0.068487
# 11      11                  addr_state:OK_TN_MO_LA_MD_NC     -0.070422
# 12      12                                 addr_state:CA     -0.076130
# 13      13                        addr_state:UT_KY_AZ_NJ     -0.090757
# 14      14                     addr_state:AR_MI_PA_OH_MN     -0.144463
# 15      15                     addr_state:RI_MA_DE_SD_IN     -0.108486
# 16      16                           addr_state:GA_WA_OR     -0.196587
# 17      17                              addr_state:WI_MT     -0.238044
# 18      18                                 addr_state:TX     -0.235403
# 19      19                              addr_state:IL_CT     -0.276107
# 20      20                  addr_state:KS_SC_CO_VT_AK_MS     -0.346185
# 21      21                  addr_state:WV_NH_WY_DC_ME_ID     -0.532143
# 22      22              verification_status:Not Verified     -0.085403
# 23      23           verification_status:Source Verified      0.009270
# 24      24                           purpose:credit_card     -0.278639
# 25      25                    purpose:debt_consolidation     -0.178795
# 26      26                    purpose:oth__med__vacation     -0.200195
# 27      27           purpose:major_purch__car__home_impr     -0.253347
# 28      28                         initial_list_status:w     -0.052342
# 29      29                                       term:36     -0.070272
# 30      30                                  emp_length:1     -0.097493
# 31      31                                emp_length:2-4     -0.129849
# 32      32                                emp_length:5-6     -0.096627
# 33      33                                emp_length:7-9     -0.067485
# 34      34                                 emp_length:10     -0.132494
# 35      35                        mths_since_issue_d:<38     -1.138992
# 36      36                      mths_since_issue_d:38-39     -0.912410
# 37      37                      mths_since_issue_d:40-41     -0.823573
# 38      38                      mths_since_issue_d:42-48     -0.625728
# 39      39                      mths_since_issue_d:49-52     -0.472437
# 40      40                      mths_since_issue_d:53-64     -0.225799
# 41      41                      mths_since_issue_d:65-84      0.030679
# 42      42                               int_rate:<9.548     -0.947824
# 43      43                         int_rate:9.548-12.025     -0.607130
# 44      44                         int_rate:12.025-15.74     -0.353838
# 45      45                         int_rate:15.74-20.281     -0.148072
# 46      46           mths_since_earliest_cr_line:141-164     -0.055357
# 47      47           mths_since_earliest_cr_line:165-247     -0.037786
# 48      48           mths_since_earliest_cr_line:248-270     -0.081576
# 49      49           mths_since_earliest_cr_line:271-352     -0.123195
# 50      50              mths_since_earliest_cr_line:>352     -0.122856
# 51      51                              inq_last_6mths:0     -0.267295
# 52      52                            inq_last_6mths:1-2     -0.124940
# 53      53                            inq_last_6mths:3-6      0.083733
# 54      54                            acc_now_delinq:>=1     -0.143598
# 55      55                            annual_inc:20K-30K      0.196162
# 56      56                            annual_inc:30K-40K      0.135578
# 57      57                            annual_inc:40K-50K      0.044705
# 58      58                            annual_inc:50K-60K     -0.021923
# 59      59                            annual_inc:60K-70K     -0.092344
# 60      60                            annual_inc:70K-80K     -0.167604
# 61      61                            annual_inc:80K-90K     -0.237180
# 62      62                           annual_inc:90K-100K     -0.264362
# 63      63                          annual_inc:100K-120K     -0.340167
# 64      64                          annual_inc:120K-140K     -0.403604
# 65      65                              annual_inc:>140K     -0.376088
# 66      66                                     dti:<=1.4     -0.044335
# 67      67                                   dti:1.4-3.5     -0.143463
# 68      68                                   dti:3.5-7.7     -0.188775
# 69      69                                  dti:7.7-10.5     -0.128609
# 70      70                                 dti:10.5-16.1     -0.052064
# 71      71                                 dti:16.1-20.3      0.048309
# 72      72                                 dti:20.3-21.7      0.054907
# 73      73                                 dti:21.7-22.4      0.097961
# 74      74                                   dti:22.4-35      0.138627
# 75      75                mths_since_last_delinq:Missing     -0.054715
# 76      76                   mths_since_last_delinq:4-30     -0.081572
# 77      77                  mths_since_last_delinq:31-56     -0.129250
# 78      78                   mths_since_last_delinq:>=57     -0.082053
# 79      79                mths_since_last_record:Missing     -0.104441
# 80      80                   mths_since_last_record:3-20     -0.221704
# 81      81                  mths_since_last_record:21-31     -0.155567
# 82      82                  mths_since_last_record:32-80     -0.279192
# 83      83                  mths_since_last_record:81-86      0.069623
# 84      84                    mths_since_last_record:>86     -0.019178
# 85       0                                       grade:G      0.000000
# 86       1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 87       2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 88       3                  verification_status:Verified      0.000000
# 89       4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 90       5                         initial_list_status:f      0.000000
# 91       6                                       term:60      0.000000
# 92       7                                  emp_length:0      0.000000
# 93       8                        mths_since_issue_d:>84      0.000000
# 94       9                              int_rate:>20.281      0.000000
# 95      10              mths_since_earliest_cr_line:<140      0.000000
# 96      11                             inq_last_6mths:>6      0.000000
# 97      12                              acc_now_delinq:0      0.000000
# 98      13                               annual_inc:<20K      0.000000
# 99      14                                       dti:>35      0.000000
# 100     15                    mths_since_last_delinq:0-3      0.000000
# 101     16                    mths_since_last_record:0-2      0.000000
#
#           p_values        Original feature name  Score - Calculation  \
# 0              NaN                    Intercept           349.371220
# 1     5.228543e-36                        grade            79.380181
# 2     1.444867e-48                        grade            58.898431
# 3     5.078288e-35                        grade            42.119006
# 4     2.345055e-21                        grade            26.052998
# 5     4.065619e-12                        grade            12.788518
# 6     3.842305e-03                        grade            -3.765882
# 7     2.957628e-06               home_ownership             6.971098
# 8     4.055983e-17               home_ownership             9.058840
# 9     2.297686e-01                   addr_state             4.170351
# 10    1.580057e-02                   addr_state             5.914413
# 11    8.261890e-03                   addr_state             6.081528
# 12    2.328402e-03                   addr_state             6.574489
# 13    1.367798e-03                   addr_state             7.837641
# 14    1.244014e-09                   addr_state            12.475578
# 15    6.103984e-04                   addr_state             9.368647
# 16    2.309147e-12                   addr_state            16.976940
# 17    3.382059e-07                   addr_state            20.557119
# 18    7.516273e-18                   addr_state            20.328970
# 19    1.967860e-19                   addr_state            23.844140
# 20    1.465993e-25                   addr_state            29.895995
# 21    5.825112e-23                   addr_state            45.954989
# 22    5.521459e-09          verification_status             7.375277
# 23    4.033018e-01          verification_status            -0.800570
# 24    1.675732e-26                      purpose            24.062758
# 25    2.714947e-14                      purpose            15.440427
# 26    6.923052e-12                      purpose            17.288486
# 27    2.049396e-17                      purpose            21.878639
# 28    3.416099e-05          initial_list_status             4.520166
# 29    2.451245e-08                         term             6.068533
# 30    1.340395e-04                   emp_length             8.419358
# 31    4.149322e-11                   emp_length            11.213556
# 32    2.413170e-05                   emp_length             8.344534
# 33    3.329767e-03                   emp_length             5.827866
# 34    8.428200e-12                   emp_length            11.441931
# 35   4.771942e-179           mths_since_issue_d            98.361460
# 36   3.275977e-148           mths_since_issue_d            78.794186
# 37   5.639309e-122           mths_since_issue_d            71.122370
# 38    1.945723e-85           mths_since_issue_d            54.036851
# 39    1.242287e-38           mths_since_issue_d            40.798883
# 40    1.238312e-07           mths_since_issue_d            19.499612
# 41    9.489601e-04           mths_since_issue_d            -2.649426
# 42    1.060389e-30                     int_rate            81.852495
# 43    6.349835e-35                     int_rate            52.430746
# 44    2.871065e-16                     int_rate            30.556839
# 45    1.281457e-04                     int_rate            12.787256
# 46    6.120157e-02  mths_since_earliest_cr_line             4.780551
# 47    1.914854e-01  mths_since_earliest_cr_line             3.263130
# 48    1.067262e-02  mths_since_earliest_cr_line             7.044809
# 49    3.611655e-06  mths_since_earliest_cr_line            10.638893
# 50    5.335146e-05  mths_since_earliest_cr_line            10.609609
# 51    5.150038e-10               inq_last_6mths            23.083144
# 52    7.236550e-07               inq_last_6mths            10.789650
# 53    1.862575e-03               inq_last_6mths            -7.231016
# 54    6.396446e-02               acc_now_delinq            12.400878
# 55    1.051865e-01                   annual_inc           -16.940227
# 56    9.001588e-01                   annual_inc           -11.708252
# 57    2.864444e-02                   annual_inc            -3.860632
# 58    1.563247e-04                   annual_inc             1.893233
# 59    4.210979e-08                   annual_inc             7.974672
# 60    1.375474e-12                   annual_inc            14.473964
# 61    1.855527e-17                   annual_inc            20.482487
# 62    5.535245e-18                   annual_inc            22.829880
# 63    2.003728e-25                   annual_inc            29.376283
# 64    6.624766e-28                   annual_inc            34.854595
# 65    3.943226e-26                   annual_inc            32.478371
# 66    3.520154e-03                          dti             3.828712
# 67    5.977388e-07                          dti            12.389236
# 68    2.028858e-09                          dti            16.302323
# 69    4.657782e-07                          dti            11.106490
# 70    8.369092e-05                          dti             4.496126
# 71    2.027027e-02                          dti            -4.171885
# 72    4.074991e-02                          dti            -4.741658
# 73    1.531979e-01                          dti            -8.459742
# 74    3.595815e-01                          dti           -11.971590
# 75    2.824465e-02       mths_since_last_delinq             4.725099
# 76    6.877103e-03       mths_since_last_delinq             7.044459
# 77    4.209465e-04       mths_since_last_delinq            11.161797
# 78    9.611698e-03       mths_since_last_delinq             7.085922
# 79    3.769795e-05       mths_since_last_record             9.019380
# 80    1.932350e-04       mths_since_last_record            19.145973
# 81    7.901537e-04       mths_since_last_record            13.434466
# 82    1.516691e-09       mths_since_last_record            24.110518
# 83    5.936840e-02       mths_since_last_record            -6.012510
# 84    2.650404e-03       mths_since_last_record             1.656150
# 85             NaN                        grade            -0.000000
# 86             NaN               home_ownership            -0.000000
# 87             NaN                   addr_state            -0.000000
# 88             NaN          verification_status            -0.000000
# 89             NaN                      purpose            -0.000000
# 90             NaN          initial_list_status            -0.000000
# 91             NaN                         term            -0.000000
# 92             NaN                   emp_length            -0.000000
# 93             NaN           mths_since_issue_d            -0.000000
# 94             NaN                     int_rate            -0.000000
# 95             NaN  mths_since_earliest_cr_line            -0.000000
# 96             NaN               inq_last_6mths            -0.000000
# 97             NaN               acc_now_delinq            -0.000000
# 98             NaN                   annual_inc            -0.000000
# 99             NaN                          dti            -0.000000
# 100            NaN       mths_since_last_delinq            -0.000000
# 101            NaN       mths_since_last_record            -0.000000
#
#      Score - Preliminary  Difference  Score - Final
# 0                  349.0   -0.371220          349.0
# 1                   79.0   -0.380181           79.0
# 2                   59.0    0.101569           59.0
# 3                   42.0   -0.119006           42.0
# 4                   26.0   -0.052998           26.0
# 5                   13.0    0.211482           13.0
# 6                   -4.0   -0.234118           -4.0
# 7                    7.0    0.028902            7.0
# 8                    9.0   -0.058840            9.0
# 9                    4.0   -0.170351            4.0
# 10                   6.0    0.085587            6.0
# 11                   6.0   -0.081528            6.0
# 12                   7.0    0.425511            7.0
# 13                   8.0    0.162359            8.0
# 14                  12.0   -0.475578           12.0
# 15                   9.0   -0.368647            9.0
# 16                  17.0    0.023060           17.0
# 17                  21.0    0.442881           21.0
# 18                  20.0   -0.328970           20.0
# 19                  24.0    0.155860           24.0
# 20                  30.0    0.104005           30.0
# 21                  46.0    0.045011           46.0
# 22                   7.0   -0.375277            7.0
# 23                  -1.0   -0.199430           -1.0
# 24                  24.0   -0.062758           24.0
# 25                  15.0   -0.440427           15.0
# 26                  17.0   -0.288486           17.0
# 27                  22.0    0.121361           22.0
# 28                   5.0    0.479834            5.0
# 29                   6.0   -0.068533            6.0
# 30                   8.0   -0.419358            8.0
# 31                  11.0   -0.213556           11.0
# 32                   8.0   -0.344534            8.0
# 33                   6.0    0.172134            6.0
# 34                  11.0   -0.441931           11.0
# 35                  98.0   -0.361460           98.0
# 36                  79.0    0.205814           79.0
# 37                  71.0   -0.122370           71.0
# 38                  54.0   -0.036851           54.0
# 39                  41.0    0.201117           41.0
# 40                  19.0   -0.499612           19.0
# 41                  -3.0   -0.350574           -3.0
# 42                  82.0    0.147505           82.0
# 43                  52.0   -0.430746           52.0
# 44                  31.0    0.443161           31.0
# 45                  13.0    0.212744           13.0
# 46                   5.0    0.219449            5.0
# 47                   3.0   -0.263130            3.0
# 48                   7.0   -0.044809            7.0
# 49                  11.0    0.361107           11.0
# 50                  11.0    0.390391           11.0
# 51                  23.0   -0.083144           23.0
# 52                  11.0    0.210350           11.0
# 53                  -7.0    0.231016           -7.0
# 54                  12.0   -0.400878           12.0
# 55                 -17.0   -0.059773          -17.0
# 56                 -12.0   -0.291748          -12.0
# 57                  -4.0   -0.139368           -4.0
# 58                   2.0    0.106767            2.0
# 59                   8.0    0.025328            8.0
# 60                  14.0   -0.473964           14.0
# 61                  20.0   -0.482487           20.0
# 62                  23.0    0.170120           23.0
# 63                  29.0   -0.376283           29.0
# 64                  35.0    0.145405           35.0
# 65                  32.0   -0.478371           32.0
# 66                   4.0    0.171288            4.0
# 67                  12.0   -0.389236           12.0
# 68                  16.0   -0.302323           16.0
# 69                  11.0   -0.106490           11.0
# 70                   4.0   -0.496126            4.0
# 71                  -4.0    0.171885           -4.0
# 72                  -5.0   -0.258342           -5.0
# 73                  -8.0    0.459742           -8.0
# 74                 -12.0   -0.028410          -12.0
# 75                   5.0    0.274901            5.0
# 76                   7.0   -0.044459            7.0
# 77                  11.0   -0.161797           15.0
# 78                   7.0   -0.085922            7.0
# 79                   9.0   -0.019380            9.0
# 80                  19.0   -0.145973           19.0
# 81                  13.0   -0.434466           13.0
# 82                  24.0   -0.110518           24.0
# 83                  -6.0    0.012510           -6.0
# 84                   2.0    0.343850            2.0
# 85                  -0.0    0.000000           -0.0
# 86                  -0.0    0.000000           -0.0
# 87                  -0.0    0.000000           -0.0
# 88                  -0.0    0.000000           -0.0
# 89                  -0.0    0.000000           -0.0
# 90                  -0.0    0.000000           -0.0
# 91                  -0.0    0.000000           -0.0
# 92                  -0.0    0.000000           -0.0
# 93                  -0.0    0.000000           -0.0
# 94                  -0.0    0.000000           -0.0
# 95                  -0.0    0.000000           -0.0
# 96                  -0.0    0.000000           -0.0
# 97                  -0.0    0.000000           -0.0
# 98                  -0.0    0.000000           -0.0
# 99                  -0.0    0.000000           -0.0
# 100                 -0.0    0.000000           -0.0
# 101                 -0.0    0.000000           -0.0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat

# %%
inputs_test_with_ref_cat_w_intercept.insert(0, 'Intercept', 1)
# We insert a column in the dataframe, with an index of 0, that is, in the beginning of the dataframe.
# The name of that column is 'Intercept', and its values are 1s.

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         grade:G  home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514        0                                   0                   0
# 288564        0                                   0                   0
# 213591        0                                   0                   0
# 263083        0                                   0                   0
# 165001        0                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  mths_since_earliest_cr_line:<140  \
# 362514                 0                                 0
# 288564                 1                                 0
# 213591                 0                                 0
# 263083                 0                                 1
# 165001                 0                                 0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         inq_last_6mths:>6  acc_now_delinq:0  acc_now_delinq:>=1  \
# 362514                  0                 1                   0
# 288564                  0                 1                   0
# 213591                  0                 1                   0
# 263083                  0                 1                   0
# 165001                  0                 1                   0
#
#         annual_inc:<20K  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                0                   0                   0
# 288564                0                   0                   0
# 213591                0                   0                   0
# 263083                0                   0                   0
# 165001                0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  dti:>35  \
# 362514              0              0              0            0        0
# 288564              0              0              0            1        0
# 213591              0              0              0            0        0
# 263083              1              0              0            0        0
# 165001              0              0              0            0        0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:0-3  \
# 362514                               1                           0
# 288564                               0                           1
# 213591                               0                           0
# 263083                               1                           0
# 165001                               0                           0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>86
# 362514                             0                           0
# 288564                             0                           0
# 213591                             0                           0
# 263083                             0                           0
# 165001                             0                           0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat_w_intercept[df_scorecard['Feature name'].values]
# Here, from the 'inputs_test_with_ref_cat_w_intercept' dataframe, we keep only the columns with column names,
# exactly equal to the row values of the 'Feature name' column from the 'df_scorecard' dataframe.

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  addr_state:CA  \
# 362514              0                             0              1
# 288564              0                             0              0
# 213591              0                             0              0
# 263083              0                             0              0
# 165001              0                             0              0
#
#         addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514                       0                          0
# 288564                       0                          0
# 213591                       1                          0
# 263083                       0                          1
# 165001                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  purpose:credit_card  \
# 362514                                    0                    0
# 288564                                    0                    1
# 213591                                    0                    0
# 263083                                    1                    0
# 165001                                    0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:w  term:36  \
# 362514                                    1                      0        0
# 288564                                    0                      1        0
# 213591                                    0                      0        1
# 263083                                    0                      1        0
# 165001                                    0                      0        1
#
#         emp_length:1  emp_length:2-4  emp_length:5-6  emp_length:7-9  \
# 362514             0               0               0               0
# 288564             0               0               0               0
# 213591             1               0               0               0
# 263083             0               1               0               0
# 165001             0               0               0               0
#
#         emp_length:10  mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514              0                       0                         0
# 288564              1                       0                         1
# 213591              0                       0                         0
# 263083              0                       1                         0
# 165001              1                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  int_rate:<9.548  int_rate:9.548-12.025  \
# 362514                         0                0                      0
# 288564                         0                0                      0
# 213591                         1                0                      0
# 263083                         0                0                      0
# 165001                         0                1                      0
#
#         int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      1                      0
# 288564                      0                      0
# 213591                      1                      0
# 263083                      1                      0
# 165001                      0                      0
#
#         mths_since_earliest_cr_line:141-164  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:165-247  \
# 362514                                    1
# 288564                                    1
# 213591                                    1
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:248-270  \
# 362514                                    0
# 288564                                    0
# 213591                                    0
# 263083                                    0
# 165001                                    0
#
#         mths_since_earliest_cr_line:271-352  mths_since_earliest_cr_line:>352  \
# 362514                                    0                                 0
# 288564                                    0                                 0
# 213591                                    0                                 0
# 263083                                    0                                 0
# 165001                                    0                                 1
#
#         inq_last_6mths:0  inq_last_6mths:1-2  inq_last_6mths:3-6  \
# 362514                 1                   0                   0
# 288564                 1                   0                   0
# 213591                 1                   0                   0
# 263083                 1                   0                   0
# 165001                 1                   0                   0
#
#         acc_now_delinq:>=1  annual_inc:20K-30K  annual_inc:30K-40K  \
# 362514                   0                   0                   0
# 288564                   0                   0                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   0
# 165001                   0                   0                   0
#
#         annual_inc:40K-50K  annual_inc:50K-60K  annual_inc:60K-70K  \
# 362514                   0                   0                   1
# 288564                   0                   1                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   1
# 165001                   0                   0                   0
#
#         annual_inc:70K-80K  annual_inc:80K-90K  annual_inc:90K-100K  \
# 362514                   0                   0                    0
# 288564                   0                   0                    0
# 213591                   0                   0                    0
# 263083                   0                   0                    0
# 165001                   0                   1                    0
#
#         annual_inc:100K-120K  annual_inc:120K-140K  annual_inc:>140K  \
# 362514                     0                     0                 0
# 288564                     0                     0                 0
# 213591                     0                     0                 1
# 263083                     0                     0                 0
# 165001                     0                     0                 0
#
#         dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  \
# 362514          0            0            0             1              0
# 288564          0            0            0             0              0
# 213591          0            0            0             0              1
# 263083          0            0            0             0              0
# 165001          0            0            0             1              0
#
#         dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  \
# 362514              0              0              0            0
# 288564              0              0              0            1
# 213591              0              0              0            0
# 263083              1              0              0            0
# 165001              0              0              0            0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:4-30  \
# 362514                               1                            0
# 288564                               0                            0
# 213591                               0                            0
# 263083                               1                            0
# 165001                               0                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:3-20  \
# 362514                               1                            0
# 288564                               1                            0
# 213591                               1                            0
# 263083                               1                            0
# 165001                               1                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>86  grade:G  \
# 362514                             0                           0        0
# 288564                             0                           0        0
# 213591                             0                           0        0
# 263083                             0                           0        0
# 165001                             0                           0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                                   0                                0
# 288564                                   0                                0
# 213591                                   0                                0
# 263083                                   0                                0
# 165001                                   0                                0
#
#         verification_status:Verified  \
# 362514                             1
# 288564                             1
# 213591                             1
# 263083                             0
# 165001                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  initial_list_status:f  \
# 362514                                             0                      1
# 288564                                             0                      0
# 213591                                             0                      1
# 263083                                             0                      0
# 165001                                             0                      1
#
#         term:60  emp_length:0  mths_since_issue_d:>84  int_rate:>20.281  \
# 362514        1             1                       0                 0
# 288564        1             0                       0                 1
# 213591        0             0                       0                 0
# 263083        1             0                       0                 0
# 165001        0             0                       0                 0
#
#         mths_since_earliest_cr_line:<140  inq_last_6mths:>6  acc_now_delinq:0  \
# 362514                                 0                  0                 1
# 288564                                 0                  0                 1
# 213591                                 0                  0                 1
# 263083                                 1                  0                 1
# 165001                                 0                  0                 1
#
#         annual_inc:<20K  dti:>35  mths_since_last_delinq:0-3  \
# 362514                0        0                           0
# 288564                0        0                           1
# 213591                0        0                           0
# 263083                0        0                           0
# 165001                0        0                           0
#
#         mths_since_last_record:0-2
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0

# %%
scorecard_scores = df_scorecard['Score - Final']

# %%
inputs_test_with_ref_cat_w_intercept.shape
# Out:
# (93257, 102)

# %%
scorecard_scores.shape
# Out:
# (102,)

# %%
scorecard_scores = scorecard_scores.values.reshape(102, 1)

# %%
scorecard_scores.shape
# Out:
# (102, 1)

# %%
y_scores = inputs_test_with_ref_cat_w_intercept.dot(scorecard_scores)
# Here we multiply the values of each row of the dataframe by the values of each column of the variable,
# which is an argument of the 'dot' method, and sum them. It's essentially the sum of the products.

# %%
y_scores.head()
# Out:
#             0
# 362514  590.0
# 288564  524.0
# 213591  551.0
# 263083  612.0
# 165001  671.0

# %%
y_scores.tail()
# Out:
#             0
# 115     543.0
# 296284  663.0
# 61777   684.0
# 91763   649.0
# 167512  631.0

# %% [markdown]
# ### From Credit Score to PD

# %%
sum_coef_from_score = ((y_scores - min_score) / (max_score - min_score)) * (max_sum_coef - min_sum_coef) + min_sum_coef
# We divide the difference between the scores and the minimum score by
# the difference between the maximum score and the minimum score.
# Then, we multiply that by the difference between the maximum sum of coefficients and the minimum sum of coefficients.
# Then, we add the minimum sum of coefficients.

# %%
y_hat_proba_from_score = np.exp(sum_coef_from_score) / (np.exp(sum_coef_from_score) + 1)
# Here we divide an exponent raised to sum of coefficients from score by
# an exponent raised to sum of coefficients from score plus one.
y_hat_proba_from_score.head()
# Out:
#                0
# 362514  0.075821
# 288564  0.149788
# 213591  0.114162
# 263083  0.059789
# 165001  0.031114

# %%
y_hat_test_proba[0: 5]
# Out:
# array([0.07594055, 0.14876786, 0.11566415, 0.0591759 , 0.03144712])

# %%
df_actual_predicted_probs['y_hat_test_proba'].head()
# Out:
# 0    0.511117
# 1    0.503247
# 2    0.500960
# 3    0.480914
# 4    0.477761
# Name: y_hat_test_proba, dtype: float64

# %% [markdown]
# ### Setting Cut-offs

# %%
# We need the confusion matrix again.
#np.where(np.squeeze(np.array(loan_data_targets_test)) == np.where(y_hat_test_proba >= tr, 1, 0), 1, 0).sum() / loan_data_targets_test.shape[0]
tr = 0.1
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)
#df_actual_predicted_probs['loan_data_targets_test'] == np.where(df_actual_predicted_probs['y_hat_test_proba'] >= tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted      0      1
# Actual
# 0          47188  35879
# 1           2812   7378

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Out:
# Predicted         0         1
# Actual
# 0          0.506000  0.384733
# 1          0.030153  0.079115

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Out:
# 0.5851142541578649

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Out:
# (array([0.00000000e+00, 0.00000000e+00, 1.20384750e-05, ...,
#         9.99855538e-01, 9.99855538e-01, 1.00000000e+00]),
#  array([0.00000000e+00, 9.81354269e-05, 9.81354269e-05, ...,
#         9.99901865e-01, 1.00000000e+00, 1.00000000e+00]),
#  array([       inf, 0.51111718, 0.503247  , ..., 0.00955576, 0.00955506,
#         0.00759682]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
thresholds
# Out:
# array([       inf, 0.51111718, 0.503247  , ..., 0.00955576, 0.00955506,
#        0.00759682])

# %%
thresholds.shape
# Out:
# (17345,)

# %%
df_cutoffs = pd.concat([pd.DataFrame(thresholds), pd.DataFrame(fpr), pd.DataFrame(tpr)], axis = 1)
# We concatenate 3 dataframes along the columns.

# %%
df_cutoffs.columns = ['thresholds', 'fpr', 'tpr']
# We name the columns of the dataframe 'thresholds', 'fpr', and 'tpr'.

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr
# 0         inf  0.000000  0.000000
# 1    0.511117  0.000000  0.000098
# 2    0.503247  0.000012  0.000098
# 3    0.500960  0.000012  0.000196
# 4    0.480914  0.000024  0.000196

# %%
df_cutoffs['thresholds'][0] = 1 - 1 / np.power(10, 16)
# Let the first threshold (the value of the thresholds column with index 0) be equal to a number, very close to 1
# but smaller than 1, say 1 - 1 / 10 ^ 16.
# Out:
# C:\Users\Pierre Pro\AppData\Local\Temp\ipykernel_10000\2460372339.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cutoffs['thresholds'][0] = 1 - 1 / np.power(10, 16)

# %%
df_cutoffs['Score'] = ((np.log(df_cutoffs['thresholds'] / (1 - df_cutoffs['thresholds'])) - min_sum_coef) * ((max_score - min_score) / (max_sum_coef - min_sum_coef)) + min_score).round()
# The score corresponsing to each threshold equals:
# The difference between the natural logarithm of the ratio of the threshold and 1 minus the threshold and
# the minimum sum of coefficients
# multiplied by
# the sum of the minimum score and the ratio of the difference between the maximum score and minimum score and 
# the difference between the maximum sum of coefficients and the minimum sum of coefficients.

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr   Score
# 0    1.000000  0.000000  0.000000 -1470.0
# 1    0.511117  0.000000  0.000098   370.0
# 2    0.503247  0.000012  0.000098   373.0
# 3    0.500960  0.000012  0.000196   374.0
# 4    0.480914  0.000024  0.000196   381.0

# %%
df_cutoffs['Score'][0] = max_score
# Out:
# C:\Users\Pierre Pro\AppData\Local\Temp\ipykernel_10000\3137964156.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cutoffs['Score'][0] = max_score

# %%
df_cutoffs.head()
# Out:
#    thresholds       fpr       tpr  Score
# 0    1.000000  0.000000  0.000000  850.0
# 1    0.511117  0.000000  0.000098  370.0
# 2    0.503247  0.000012  0.000098  373.0
# 3    0.500960  0.000012  0.000196  374.0
# 4    0.480914  0.000024  0.000196  381.0

# %%
df_cutoffs.tail()
# Out:
#        thresholds       fpr       tpr  Score
# 17340    0.010389  0.999567  0.999804  768.0
# 17341    0.010384  0.999567  0.999902  768.0
# 17342    0.009556  0.999856  0.999902  775.0
# 17343    0.009555  0.999856  1.000000  775.0
# 17344    0.007597  1.000000  1.000000  795.0

# %%
# We define a function called 'n_approved' which assigns a value of 1 if a predicted probability
# is greater than the parameter p, which is a threshold, and a value of 0, if it is not.
# Then it sums the column.
# Thus, if given any percentage values, the function will return
# the number of rows wih estimated probabilites greater than the threshold. 
def n_approved(p):
    return np.where(df_actual_predicted_probs['y_hat_test_proba'] >= p, 1, 0).sum()

# %%
df_cutoffs['N Approved'] = df_cutoffs['thresholds'].apply(n_approved)
# Assuming that all credit applications above a given probability of being 'good' will be approved,
# when we apply the 'n_approved' function to a threshold, it will return the number of approved applications.
# Thus, here we calculate the number of approved appliations for al thresholds.
df_cutoffs['N Rejected'] = df_actual_predicted_probs['y_hat_test_proba'].shape[0] - df_cutoffs['N Approved']
# Then, we calculate the number of rejected applications for each threshold.
# It is the difference between the total number of applications and the approved applications for that threshold.
df_cutoffs['Approval Rate'] = df_cutoffs['N Approved'] / df_actual_predicted_probs['y_hat_test_proba'].shape[0]